# %% [markdown]
# # Artificial Intelligence Engineer Nanodegree - Probabilistic Models
# ## Project: Sign Language Recognition System
# - [Introduction](#intro)
# - [Part 1 Feature Selection](#part1_tutorial)
#     - [Tutorial](#part1_tutorial)
#     - [Features Submission](#part1_submission)
#     - [Features Unittest](#part1_test)
# - [Part 2 Train the models](#part2_tutorial)
#     - [Tutorial](#part2_tutorial)
#     - [Model Selection Score Submission](#part2_submission)
#     - [Model Score Unittest](#part2_test)
# - [Part 3 Build a Recognizer](#part3_tutorial)
#     - [Tutorial](#part3_tutorial)
#     - [Recognizer Submission](#part3_submission)
#     - [Recognizer Unittest](#part3_test)
# - [Part 4 (OPTIONAL) Improve the WER with Language Models](#part4_info)

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# The overall goal of this project is to build a word recognizer for American Sign Language video sequences, demonstrating the power of probabalistic models.  In particular, this project employs  [hidden Markov models (HMM's)](https://en.wikipedia.org/wiki/Hidden_Markov_model) to analyze a series of measurements taken from videos of American Sign Language (ASL) collected for research (see the [RWTH-BOSTON-104 Database](http://www-i6.informatik.rwth-aachen.de/~dreuw/database-rwth-boston-104.php)).  In this video, the right-hand x and y locations are plotted as the speaker signs the sentence.
# [![ASLR demo](http://www-i6.informatik.rwth-aachen.de/~dreuw/images/demosample.png)](https://drive.google.com/open?id=0B_5qGuFe-wbhUXRuVnNZVnMtam8)
#
# The raw data, train, and test sets are pre-defined.  You will derive a variety of feature sets (explored in Part 1), as well as implement three different model selection criterion to determine the optimal number of hidden states for each word model (explored in Part 2). Finally, in Part 3 you will implement the recognizer and compare the effects the different combinations of feature sets and model selection criteria.
#
# At the end of each Part, complete the submission cells with implementations, answer all questions, and pass the unit tests.  Then submit the completed notebook for review!

# %% [markdown]
# <a id='part1_tutorial'></a>
# ## PART 1: Data
#
# ### Features Tutorial
# ##### Load the initial database
# A data handler designed for this database is provided in the student codebase as the `AslDb` class in the `asl_data` module.  This handler creates the initial [pandas](http://pandas.pydata.org/pandas-docs/stable/) dataframe from the corpus of data included in the `data` directory as well as dictionaries suitable for extracting data in a format friendly to the [hmmlearn](https://hmmlearn.readthedocs.io/en/latest/) library.  We'll use those to create models in Part 2.
#
# To start, let's set up the initial database and select an example set of features for the training set.  At the end of Part 1, you will create additional feature sets for experimentation.

# %%
import numpy as np
import pandas as pd
from asl_data import AslDb


asl = AslDb() # initializes the database
asl.df.head() # displays the first five rows of the asl database, indexed by video and frame
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1

# %%
asl.df.ix[98,1]  # look at the data available for an individual frame
# Out:
# left-x         149
# left-y         181
# right-x        170
# right-y        175
# nose-x         161
# nose-y          62
# speaker    woman-1
# Name: (98, 1), dtype: object

# %% [markdown]
# The frame represented by video 98, frame 1 is shown here:
# ![Video 98](http://www-i6.informatik.rwth-aachen.de/~dreuw/database/rwth-boston-104/overview/images/orig/098-start.jpg)

# %% [markdown]
# ##### Feature selection for training the model
# The objective of feature selection when training a model is to choose the most relevant variables while keeping the model as simple as possible, thus reducing training time.  We can use the raw features already provided or derive our own and add columns to the pandas dataframe `asl.df` for selection. As an example, in the next cell a feature named `'grnd-ry'` is added. This feature is the difference between the right-hand y value and the nose y value, which serves as the "ground" right y value.

# %%
asl.df['grnd-ry'] = asl.df['right-y'] - asl.df['nose-y']
asl.df.head()  # the new feature 'grnd-ry' is now in the frames dictionary
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry
# video frame
# 98    0          113
#       1          113
#       2          113
#       3          113
#       4          113

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_features_tryit
# TODO add df columns for 'grnd-rx', 'grnd-ly', 'grnd-lx' representing differences between hand and nose locations
asl.df['grnd-rx'] = asl.df['right-x'] - asl.df['nose-x']
asl.df['grnd-ly'] = asl.df['left-y'] - asl.df['nose-y']
asl.df['grnd-lx'] = asl.df['left-x'] - asl.df['nose-x']
# test the code
test_features_tryit(asl)
# Out:
# asl.df sample
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx
# video frame
# 98    0          113        9      119      -12
#       1          113        9      119      -12
#       2          113        9      119      -12
#       3          113        9      119      -12
#       4          113        9      119      -12
# <font color=green>Correct!</font><br/>

# %%
# collect the features into a list
features_ground = ['grnd-rx','grnd-ry','grnd-lx','grnd-ly']
 #show a single set of features for a given (video, frame) tuple
[asl.df.ix[98,1][v] for v in features_ground]
# Out:
# [9, 113, -12, 119]

# %% [markdown]
# ##### Build the training set
# Now that we have a feature list defined, we can pass that list to the `build_training` method to collect the features for all the words in the training set.  Each word in the training set has multiple examples from various videos.  Below we can see the unique words that have been loaded into the training set:

# %%
training = asl.build_training(features_ground)
print("Training words: {}".format(training.words))
# Out:
# Training words: ['JOHN', 'WRITE', 'HOMEWORK', 'IX-1P', 'SEE', 'YESTERDAY', 'IX', 'LOVE', 'MARY', 'CAN', 'GO', 'GO1', 'FUTURE', 'GO2', 'PARTY', 'FUTURE1', 'HIT', 'BLAME', 'FRED', 'FISH', 'WONT', 'EAT', 'BUT', 'CHICKEN', 'VEGETABLE', 'CHINA', 'PEOPLE', 'PREFER', 'BROCCOLI', 'LIKE', 'LEAVE', 'SAY', 'BUY', 'HOUSE', 'KNOW', 'CORN', 'CORN1', 'THINK', 'NOT', 'PAST', 'LIVE', 'CHICAGO', 'CAR', 'SHOULD', 'DECIDE', 'VISIT', 'MOVIE', 'WANT', 'SELL', 'TOMORROW', 'NEXT-WEEK', 'NEW-YORK', 'LAST-WEEK', 'WILL', 'FINISH', 'ANN', 'READ', 'BOOK', 'CHOCOLATE', 'FIND', 'SOMETHING-ONE', 'POSS', 'BROTHER', 'ARRIVE', 'HERE', 'GIVE', 'MAN', 'NEW', 'COAT', 'WOMAN', 'GIVE1', 'HAVE', 'FRANK', 'BREAK-DOWN', 'SEARCH-FOR', 'WHO', 'WHAT', 'LEG', 'FRIEND', 'CANDY', 'BLUE', 'SUE', 'BUY1', 'STOLEN', 'OLD', 'STUDENT', 'VIDEOTAPE', 'BORROW', 'MOTHER', 'POTATO', 'TELL', 'BILL', 'THROW', 'APPLE', 'NAME', 'SHOOT', 'SAY-1P', 'SELF', 'GROUP', 'JANA', 'TOY1', 'MANY', 'TOY', 'ALL', 'BOY', 'TEACHER', 'GIRL', 'BOX', 'GIVE2', 'GIVE3', 'GET', 'PUTASIDE']

# %% [markdown]
# The training data in `training` is an object of class `WordsData` defined in the `asl_data` module.  in addition to the `words` list, data can be accessed with the `get_all_sequences`, `get_all_Xlengths`, `get_word_sequences`, and `get_word_Xlengths` methods. We need the `get_word_Xlengths` method to train multiple sequences with the `hmmlearn` library.  In the following example, notice that there are two lists; the first is a concatenation of all the sequences(the X portion) and the second is a list of the sequence lengths(the Lengths portion).

# %%
training.get_word_Xlengths('CHOCOLATE')
# Out:
# (array([[-11,  48,   7, 120],
#         [-11,  48,   8, 109],
#         [ -8,  49,  11,  98],
#         [ -7,  50,   7,  87],
#         [ -4,  54,   7,  77],
#         [ -4,  54,   6,  69],
#         [ -4,  54,   6,  69],
#         [-13,  52,   6,  69],
#         [-13,  52,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [-10,  59,   7,  71],
#         [-15,  64,   9,  77],
#         [-17,  75,  13,  81],
#         [ -4,  48,  -4, 113],
#         [ -2,  53,  -4, 113],
#         [ -4,  55,   2,  98],
#         [ -4,  58,   2,  98],
#         [ -1,  59,   2,  89],
#         [ -1,  59,  -1,  84],
#         [ -1,  59,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -2,  73,   5,  90],
#         [ -3,  79,  -4,  96],
#         [-15,  98,  13, 135],
#         [ -6,  93,  12, 128],
#         [ -2,  89,  14, 118],
#         [  5,  90,  10, 108],
#         [  4,  86,   7, 105],
#         [  4,  86,   7, 105],
#         [  4,  86,  13, 100],
#         [ -3,  82,  14,  96],
#         [ -3,  82,  14,  96],
#         [  6,  89,  16, 100],
#         [  6,  89,  16, 100],
#         [  7,  85,  17, 111]], dtype=int64), [17, 20, 12])

# %% [markdown]
# ###### More feature sets
# So far we have a simple feature set that is enough to get started modeling.  However, we might get better results if we manipulate the raw values a bit more, so we will go ahead and set up some other options now for experimentation later.  For example, we could normalize each speaker's range of motion with grouped statistics using [Pandas stats](http://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-stats) functions and [pandas groupby](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html).  Below is an example for finding the means of all speaker subgroups.

# %%
df_means = asl.df.groupby('speaker').mean()
df_means
# Out:
#              left-x      left-y     right-x     right-y      nose-x  \
# speaker
# man-1    206.248203  218.679449  155.464350  150.371031  175.031756
# woman-1  164.661438  161.271242  151.017865  117.332462  162.655120
# woman-2  183.214509  176.527232  156.866295  119.835714  170.318973
#
#             nose-y    grnd-ry    grnd-rx     grnd-ly    grnd-lx
# speaker
# man-1    61.642600  88.728430 -19.567406  157.036848  31.216447
# woman-1  57.245098  60.087364 -11.637255  104.026144   2.006318
# woman-2  58.022098  61.813616 -13.452679  118.505134  12.895536

# %% [markdown]
# To select a mean that matches by speaker, use the pandas [map](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) method:

# %%
asl.df['left-x-mean']= asl.df['speaker'].map(df_means['left-x'])
asl.df.head()
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx  left-x-mean
# video frame
# 98    0          113        9      119      -12   164.661438
#       1          113        9      119      -12   164.661438
#       2          113        9      119      -12   164.661438
#       3          113        9      119      -12   164.661438
#       4          113        9      119      -12   164.661438

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_std_tryit
df_std = asl.df.groupby('speaker').std()
# test the code
test_std_tryit(df_std)
# Out:
# df_std
#             left-x     left-y    right-x    right-y    nose-x    nose-y  \
# speaker
# man-1    15.154425  36.328485  18.901917  54.902340  6.654573  5.520045
# woman-1  17.573442  26.594521  16.459943  34.667787  3.549392  3.538330
# woman-2  15.388711  28.825025  14.890288  39.649111  4.099760  3.416167
#
#            grnd-ry    grnd-rx    grnd-ly    grnd-lx  left-x-mean
# speaker
# man-1    53.487999  20.269032  36.572749  15.080360          0.0
# woman-1  33.972660  16.764706  27.117393  17.328941          0.0
# woman-2  39.128572  16.191324  29.320655  15.050938          0.0
# <font color=green>Correct!</font><br/>

# %% [markdown]
# <a id='part1_submission'></a>
# ### Features Implementation Submission
# Implement four feature sets and answer the question that follows.
# - normalized Cartesian coordinates
#     - use *mean* and *standard deviation* statistics and the [standard score](https://en.wikipedia.org/wiki/Standard_score) equation to account for speakers with different heights and arm length
#
# - polar coordinates
#     - calculate polar coordinates with [Cartesian to polar equations](https://en.wikipedia.org/wiki/Polar_coordinate_system#Converting_between_polar_and_Cartesian_coordinates)
#     - use the [np.arctan2](https://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.arctan2.html) function and *swap the x and y axes* to move the $0$ to $2\pi$ discontinuity to 12 o'clock instead of 3 o'clock;  in other words, the normal break in radians value from $0$ to $2\pi$ occurs directly to the left of the speaker's nose, which may be in the signing area and interfere with results.  By swapping the x and y axes, that discontinuity move to directly above the speaker's head, an area not generally used in signing.
#
# - delta difference
#     - as described in Thad's lecture, use the difference in values between one frame and the next frames as features
#     - pandas [diff method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.diff.html) and [fillna method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html) will be helpful for this one
#
# - custom features
#     - These are your own design; combine techniques used above or come up with something else entirely. We look forward to seeing what you come up with!
#     Some ideas to get you started:
#         - normalize using a [feature scaling equation](https://en.wikipedia.org/wiki/Feature_scaling)
#         - normalize the polar coordinates
#         - adding additional deltas

# %%
# TODO add features for normalized by speaker values of left, right, x, y
# Name these 'norm-rx', 'norm-ry', 'norm-lx', and 'norm-ly'
# using Z-score scaling (X-Xmean)/Xstd
asl.df['left-y-mean']= asl.df['speaker'].map(df_means['left-y'])
asl.df['right-x-mean']= asl.df['speaker'].map(df_means['right-x'])
asl.df['right-y-mean']= asl.df['speaker'].map(df_means['right-y'])
asl.df['left-x-std']= asl.df['speaker'].map(df_std['left-x'])
asl.df['left-y-std']= asl.df['speaker'].map(df_std['left-y'])
asl.df['right-x-std']= asl.df['speaker'].map(df_std['right-x'])
asl.df['right-y-std']= asl.df['speaker'].map(df_std['right-y'])

asl.df['norm-lx']= (asl.df['left-x']- asl.df['left-x-mean'] ) / asl.df['left-x-std']
asl.df['norm-ly']= (asl.df['left-y']- asl.df['left-y-mean'] ) / asl.df['left-y-std']
asl.df['norm-rx']= (asl.df['right-x']- asl.df['right-x-mean'] ) / asl.df['right-x-std']
asl.df['norm-ry']= (asl.df['right-y']- asl.df['right-y-mean'] ) / asl.df['right-y-std']


features_norm = ['norm-rx', 'norm-ry', 'norm-lx','norm-ly']

# %%
# TODO add features for polar coordinate values where the nose is the origin
# Name these 'polar-rr', 'polar-rtheta', 'polar-lr', and 'polar-ltheta'
# Note that 'polar-rr' and 'polar-rtheta' refer to the radius and angle
asl.df['polar-rr']=np.linalg.norm(asl.df[['grnd-ry','grnd-rx']],axis=1)
asl.df['polar-rtheta']=np.arctan2(asl.df['grnd-rx'],asl.df['grnd-ry'])
asl.df['polar-lr']=np.linalg.norm(asl.df[['grnd-ly','grnd-lx']],axis=1)
asl.df['polar-ltheta']=np.arctan2(asl.df['grnd-lx'],asl.df['grnd-ly'])

features_polar = ['polar-rr', 'polar-rtheta', 'polar-lr', 'polar-ltheta']

# %%
# TODO add features for left, right, x, y differences by one time step, i.e. the "delta" values discussed in the lecture
# Name these 'delta-rx', 'delta-ry', 'delta-lx', and 'delta-ly'
asl.df['delta-rx']=asl.df['right-x'].diff().fillna(0)
asl.df['delta-ry']=asl.df['right-y'].diff().fillna(0)
asl.df['delta-lx']=asl.df['left-x'].diff().fillna(0)
asl.df['delta-ly']=asl.df['left-y'].diff().fillna(0)
features_delta = ['delta-rx', 'delta-ry', 'delta-lx', 'delta-ly']

# %%
# TODO add features of your own design, which may be a combination of the above or something else
# Name these whatever you would like
df_means = asl.df.groupby('speaker').mean()
df_std = asl.df.groupby('speaker').std()
asl.df['polar-ltheta-mean']= asl.df['speaker'].map(df_means['polar-ltheta'])
asl.df['polar-lr-mean']= asl.df['speaker'].map(df_means['polar-lr'])
asl.df['polar-rr-mean']= asl.df['speaker'].map(df_means['polar-rr'])
asl.df['polar-rtheta-mean']= asl.df['speaker'].map(df_means['polar-rtheta'])

asl.df['polar-ltheta-std']= asl.df['speaker'].map(df_std['polar-ltheta'])
asl.df['polar-lr-std']= asl.df['speaker'].map(df_std['polar-lr'])
asl.df['polar-rr-std']= asl.df['speaker'].map(df_std['polar-rr'])
asl.df['polar-rtheta-std']= asl.df['speaker'].map(df_std['polar-rtheta'])


asl.df['norm-polar-ltheta']= (asl.df['polar-ltheta']- asl.df['polar-ltheta-mean'] ) / asl.df['polar-ltheta-std']
asl.df['norm-polar-lr']= (asl.df['polar-lr']- asl.df['polar-lr-mean'] ) / asl.df['polar-lr-std']
asl.df['norm-polar-rr']= (asl.df['polar-rr']- asl.df['polar-rr-mean'] ) / asl.df['polar-rr-std']
asl.df['norm-polar-rtheta']= (asl.df['polar-rtheta']- asl.df['polar-rtheta-mean'] ) / asl.df['polar-rtheta-std']


features_norm_polar = ['norm-polar-ltheta', 'norm-polar-lr', 'norm-polar-rr','norm-polar-rtheta']

asl.df['delta-norm-polar-ltheta']=asl.df['norm-polar-ltheta'].diff().fillna(0)
asl.df['delta-norm-polar-lr']=asl.df['norm-polar-lr'].diff().fillna(0)
asl.df['delta-norm-polar-rr']=asl.df['norm-polar-rr'].diff().fillna(0)
asl.df['delta-norm-polar-rtheta']=asl.df['norm-polar-rtheta'].diff().fillna(0)
features_delta_norm_polar = ['delta-norm-polar-ltheta', 'delta-norm-polar-lr', 'delta-norm-polar-rr', 'delta-norm-polar-rtheta']



# TODO define a list named 'features_custom' for building the training set

# %% [markdown]
# **Question 1:**  What custom features did you choose for the features_custom set and why?
#
# **Answer 1:** I use delta polar normalize features:
# I think polar coordenates better reflect  the change of position.
# The important thing is not the position, it is the movement, and the delta characteristics measure the movement better..
# A normalize feature is best to compare, and then is better for learning.

# %% [markdown]
# <a id='part1_test'></a>
# ### Features Unit Testing
# Run the following unit tests as a sanity check on the defined "ground", "norm", "polar", and 'delta"
# feature sets.  The test simply looks for some valid values but is not exhaustive.  However, the project should not be submitted if these tests don't pass.

# %%
import unittest
# import numpy as np

class TestFeatures(unittest.TestCase):

    def test_features_ground(self):
        sample = (asl.df.ix[98, 1][features_ground]).tolist()
        self.assertEqual(sample, [9, 113, -12, 119])

    def test_features_norm(self):
        sample = (asl.df.ix[98, 1][features_norm]).tolist()
        np.testing.assert_almost_equal(sample, [ 1.153,  1.663, -0.891,  0.742], 3)

    def test_features_polar(self):
        sample = (asl.df.ix[98,1][features_polar]).tolist()
        np.testing.assert_almost_equal(sample, [113.3578, 0.0794, 119.603, -0.1005], 3)

    def test_features_delta(self):
        sample = (asl.df.ix[98, 0][features_delta]).tolist()
        self.assertEqual(sample, [0, 0, 0, 0])
        sample = (asl.df.ix[98, 18][features_delta]).tolist()
        self.assertTrue(sample in [[-16, -5, -2, 4], [-14, -9, 0, 0]], "Sample value found was {}".format(sample))
                         
suite = unittest.TestLoader().loadTestsFromModule(TestFeatures())
unittest.TextTestRunner().run(suite)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.021s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part2_tutorial'></a>
# ## PART 2: Model Selection
# ### Model Selection Tutorial
# The objective of Model Selection is to tune the number of states for each word HMM prior to testing on unseen data.  In this section you will explore three methods:
# - Log likelihood using cross-validation folds (CV)
# - Bayesian Information Criterion (BIC)
# - Discriminative Information Criterion (DIC)

# %% [markdown]
# ##### Train a single word
# Now that we have built a training set with sequence data, we can "train" models for each word.  As a simple starting example, we train a single word using Gaussian hidden Markov models (HMM).   By using the `fit` method during training, the [Baum-Welch Expectation-Maximization](https://en.wikipedia.org/wiki/Baum%E2%80%93Welch_algorithm) (EM) algorithm is invoked iteratively to find the best estimate for the model *for the number of hidden states specified* from a group of sample seequences. For this example, we *assume* the correct number of hidden states is 3, but that is just a guess.  How do we know what the "best" number of states for training is?  We will need to find some model selection technique to choose the best parameter.

# %%
import warnings
from hmmlearn.hmm import GaussianHMM

def train_a_word(word, num_hidden_states, features):
    
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    training = asl.build_training(features)  
    X, lengths = training.get_word_Xlengths(word)
    model = GaussianHMM(n_components=num_hidden_states, n_iter=1000).fit(X, lengths)
    logL = model.score(X, lengths)
    return model, logL

demoword = 'BOOK'
model, logL = train_a_word(demoword, 3, features_ground)
print("Number of states trained in model for {} is {}".format(demoword, model.n_components))
print("logL = {}".format(logL))
# Out:
# Number of states trained in model for BOOK is 3
# logL = -2331.113812743318

# %% [markdown]
# The HMM model has been trained and information can be pulled from the model, including means and variances for each feature and hidden state.  The [log likelihood](http://math.stackexchange.com/questions/892832/why-we-consider-log-likelihood-instead-of-likelihood-in-gaussian-distribution) for any individual sample or group of samples can also be calculated with the `score` method.

# %%
def show_model_stats(word, model):
    print("Number of states trained in model for {} is {}".format(word, model.n_components))    
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])    
    for i in range(model.n_components):  # for each hidden state
        print("hidden state #{}".format(i))
        print("mean = ", model.means_[i])
        print("variance = ", variance[i])
        print()
    
show_model_stats(demoword, model)
# Out:
# Number of states trained in model for BOOK is 3
# hidden state #0
# mean =  [ -3.46504869  50.66686933  14.02391587  52.04731066]
# variance =  [ 49.12346305  43.04799144  39.35109609  47.24195772]
#
# hidden state #1
# mean =  [ -11.45300909   94.109178     19.03512475  102.2030162 ]
# variance =  [  77.403668    203.35441965   26.68898447  156.12444034]
#
# hidden state #2
# mean =  [ -1.12415027  69.44164191  17.02866283  77.7231196 ]
# variance =  [ 19.70434594  16.83041492  30.51552305  11.03678246]

# %% [markdown]
# ##### Try it!
# Experiment by changing the feature set, word, and/or num_hidden_states values in the next cell to see changes in values.

# %%
#my_testword = 'CHOCOLATE'
#my_testword = 'FISH'
my_testword = 'BOOK'
#model, logL = train_a_word(my_testword, 6, features_ground) # Experiment here with different parameters
#model, logL = train_a_word(my_testword, 6, features_polar)
#model, logL = train_a_word(my_testword, 6, features_delta)
model, logL = train_a_word(my_testword, 6, features_delta_norm_polar)
#model, logL = train_a_word(my_testword, 30, features_delta_norm_polar)
show_model_stats(my_testword, model)
print("logL = {}".format(logL))
# Out:
# Number of states trained in model for BOOK is 6
# hidden state #0
# mean =  [-0.02765669  0.17763751  0.12438718  0.00934954]
# variance =  [ 0.06379133  0.01621482  0.00788884  0.00780135]
#
# hidden state #1
# mean =  [-0.49984512 -0.06248993  0.03285169  0.06709562]
# variance =  [ 0.05459352  0.00545251  0.00453336  0.00844137]
#
# hidden state #2
# mean =  [ 0.18860967 -0.00927282 -0.00966142 -0.10432089]
# variance =  [ 0.08675104  0.01236486  0.00394631  0.013964  ]
#
# hidden state #3
# mean =  [-0.12796125 -0.20537441  0.13281277  0.2639925 ]
# variance =  [ 0.06984268  0.01939438  0.011883    0.05498775]
#
# hidden state #4
# mean =  [-0.31786471  0.02410803  0.0341952   0.06075237]
# variance =  [ 0.03764946  0.00529911  0.00331794  0.01323586]
#
# hidden state #5
# mean =  [  2.54064240e-04  -1.21198960e-03   1.56454258e-06  -1.40734643e-07]
# variance =  [ 0.00021591  0.00028178  0.00021305  0.00021295]
#
# logL = 803.666192467252

# %% [markdown]
# features ground + 3 hideen state : LogL=-601
# features ground + 6 hideen state : LogL=-427
# features ground + 10 hideen state : LogL=-402
# features polar + 6 hideen state : LogL=-95
# features delta + 6 hideen state : LogL=-45
# features delta polar + 6 hideen state : LogL=287
# features delta polar + 3 hideen state : LogL=243
# features delta polar + 4 hideen state : LogL=247
# features delta polar + 5 hideen state : LogL=260
# features delta polar + 7 hideen state : LogL=293
# features delta polar + 8 hideen state : LogL=293
# features delta polar + 15 hideen state : LogL=337
# features delta polar + 15 hideen state : LogL=348

# %% [markdown]
# ##### Visualize the hidden states
# We can plot the means and variances for each state and feature.  Try varying the number of states trained for the HMM model and examine the variances.  Are there some models that are "better" than others?  How can you tell?  We would like to hear what you think in the classroom online.

# %%
# %matplotlib inline

# %%
import math
from matplotlib import (cm, pyplot as plt, mlab)

def visualize(word, model):
    """ visualize the input model for a particular word """
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])
    figures = []
    for parm_idx in range(len(model.means_[0])):
        xmin = int(min(model.means_[:,parm_idx]) - max(variance[:,parm_idx]))
        xmax = int(max(model.means_[:,parm_idx]) + max(variance[:,parm_idx]))
        fig, axs = plt.subplots(model.n_components, sharex=True, sharey=False)
        colours = cm.rainbow(np.linspace(0, 1, model.n_components))
        for i, (ax, colour) in enumerate(zip(axs, colours)):
            x = np.linspace(xmin, xmax, 100)
            mu = model.means_[i,parm_idx]
            sigma = math.sqrt(np.diag(model.covars_[i])[parm_idx])
            ax.plot(x, mlab.normpdf(x, mu, sigma), c=colour)
            ax.set_title("{} feature {} hidden state #{} ".format(word, parm_idx, i))
            ax.grid(True)
        figures.append(plt)
    for p in figures:
        p.show()
        
visualize(my_testword, model)

# %% [markdown]
# #####  ModelSelector class
# Review the `SelectorModel` class from the codebase found in the `my_model_selectors.py` module.  It is designed to be a strategy pattern for choosing different model selectors.  For the project submission in this section, subclass `SelectorModel` to implement the following model selectors.  In other words, you will write your own classes/functions in the `my_model_selectors.py` module and run them from this notebook:
#
# - `SelectorCV `:  Log likelihood with CV
# - `SelectorBIC`: BIC
# - `SelectorDIC`: DIC
#
# You will train each word in the training set with a range of values for the number of hidden states, and then score these alternatives with the model selector, choosing the "best" according to each strategy. The simple case of training with a constant value for `n_components` can be called using the provided `SelectorConstant` subclass as follow:

# %%
from my_model_selectors import SelectorConstant

training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
word = 'VEGETABLE' # Experiment here with different words
model = SelectorConstant(training.get_all_sequences(), training.get_all_Xlengths(), word, n_constant=3).select()
print("Number of states trained in model for {} is {}".format(word, model.n_components))
# Out:
# Number of states trained in model for VEGETABLE is 3

# %% [markdown]
# ##### Cross-validation folds
# If we simply score the model with the Log Likelihood calculated from the feature sequences it has been trained on, we should expect that more complex models will have higher likelihoods. However, that doesn't tell us which would have a better likelihood score on unseen data.  The model will likely be overfit as complexity is added.  To estimate which topology model is better using only the training data, we can compare scores using cross-validation.  One technique for cross-validation is to break the training set into "folds" and rotate which fold is left out of training.  The "left out" fold scored.  This gives us a proxy method of finding the best model to use on "unseen data". In the following example, a set of word sequences is broken into three folds using the [scikit-learn Kfold](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) class object. When you implement `SelectorCV`, you will use this technique.

# %%
from sklearn.model_selection import KFold

training = asl.build_training(features_ground) # Experiment here with different feature sets
word = 'VEGETABLE' # Experiment here with different words
word_sequences = training.get_word_sequences(word)
split_method = KFold()
for cv_train_idx, cv_test_idx in split_method.split(word_sequences):
    print("Train fold indices:{} Test fold indices:{}".format(cv_train_idx, cv_test_idx))  # view indices of the folds
# Out:
# Train fold indices:[2 3 4 5] Test fold indices:[0 1]
# Train fold indices:[0 1 4 5] Test fold indices:[2 3]
# Train fold indices:[0 1 2 3] Test fold indices:[4 5]

# %% [markdown]
# **Tip:** In order to run `hmmlearn` training using the X,lengths tuples on the new folds, subsets must be combined based on the indices given for the folds.  A helper utility has been provided in the `asl_utils` module named `combine_sequences` for this purpose.

# %% [markdown]
# ##### Scoring models with other criterion
# Scoring model topologies with **BIC** balances fit and complexity within the training set for each word.  In the BIC equation, a penalty term penalizes complexity to avoid overfitting, so that it is not necessary to also use cross-validation in the selection process.  There are a number of references on the internet for this criterion.  These [slides](http://www2.imm.dtu.dk/courses/02433/doc/ch6_slides.pdf) include a formula you may find helpful for your implementation.
#
# The advantages of scoring model topologies with **DIC** over BIC are presented by Alain Biem in this [reference](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.58.6208&rep=rep1&type=pdf) (also found [here](https://pdfs.semanticscholar.org/ed3d/7c4a5f607201f3848d4c02dd9ba17c791fc2.pdf)).  DIC scores the discriminant ability of a training set for one word against competing words.  Instead of a penalty term for complexity, it provides a penalty if model liklihoods for non-matching words are too similar to model likelihoods for the correct word in the word set.

# %% [markdown]
# <a id='part2_submission'></a>
# ### Model Selection Implementation Submission
# Implement `SelectorCV`, `SelectorBIC`, and `SelectorDIC` classes in the `my_model_selectors.py` module.  Run the selectors on the following five words. Then answer the questions about your results.
#
# **Tip:** The `hmmlearn` library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
words_to_train = ['FISH', 'BOOK', 'VEGETABLE', 'FUTURE', 'JOHN']
import timeit
import my_model_selectors
from imp import reload

# %%
# TODO: Implement SelectorCV in my_model_selector.py
reload(my_model_selectors)
from my_model_selectors import SelectorCV


training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()
for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorCV(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# Training complete for FISH with 5 states with time 1.0609882209973875 seconds
# Training complete for BOOK with 5 states with time 17.51069175300654 seconds
# Training complete for VEGETABLE with 2 states with time 6.382440608984325 seconds
# Training complete for FUTURE with 2 states with time 18.080234813009156 seconds
# Training complete for JOHN with 12 states with time 188.00537841400364 seconds

# %%
# TODO: Implement SelectorBIC in module my_model_selectors.py
reload(my_model_selectors)
from my_model_selectors import SelectorBIC


for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorBIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# Training complete for FISH with 5 states with time 1.0587775329768192 seconds
# Training complete for BOOK with 12 states with time 7.2421532689768355 seconds
# Training complete for VEGETABLE with 15 states with time 2.368708754016552 seconds
# Training complete for FUTURE with 15 states with time 7.775466568011325 seconds
# Training complete for JOHN with 15 states with time 78.03365903100348 seconds

# %%
# TODO: Implement SelectorDIC in module my_model_selectors.py
reload(my_model_selectors)
from my_model_selectors import SelectorDIC


for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorDIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# Training complete for FISH with 3 states with time 1.889418041013414 seconds
# Training complete for BOOK with 15 states with time 10.75329105000128 seconds
# Training complete for VEGETABLE with 15 states with time 6.45733251501224 seconds
# Training complete for FUTURE with 15 states with time 11.325855745002627 seconds
# Training complete for JOHN with 15 states with time 81.16185099200811 seconds

# %% [markdown]
# **Question 2:**  Compare and contrast the possible advantages and disadvantages of the various model selectors implemented.
#
# **Answer 2:**
# In my implementation, the CV get more simple models, but it is slower.

# %% [markdown]
# <a id='part2_test'></a>
# ### Model Selector Unit Testing
# Run the following unit tests as a sanity check on the implemented model selectors.  The test simply looks for valid interfaces  but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_model_selectors import TestSelectors
suite = unittest.TestLoader().loadTestsFromModule(TestSelectors())
unittest.TextTestRunner().run(suite)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 181.538s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part3_tutorial'></a>
# ## PART 3: Recognizer
# The objective of this section is to "put it all together".  Using the four feature sets created and the three model selectors, you will experiment with the models and present your results.  Instead of training only five specific words as in the previous section, train the entire set with a feature set and model selector strategy.
# ### Recognizer Tutorial
# ##### Train the full training set
# The following example trains the entire set with the example `features_ground` and `SelectorConstant` features and model selector.  Use this pattern for you experimentation and final submission cells.

# %%
# autoreload for automatically reloading changes made in my_model_selectors and my_recognizer
# %load_ext autoreload
# %autoreload 2

from my_model_selectors import SelectorConstant

def train_all_words(features, model_selector):
    training = asl.build_training(features)  # Experiment here with different feature sets defined in part 1
    sequences = training.get_all_sequences()
    Xlengths = training.get_all_Xlengths()
    model_dict = {}
    for word in training.words:
        model = model_selector(sequences, Xlengths, word, 
                        n_constant=3).select()
        model_dict[word]=model
    return model_dict

models = train_all_words(features_ground, SelectorConstant)
print("Number of word models returned = {}".format(len(models)))
# Out:
# Number of word models returned = 112

# %% [markdown]
# ##### Load the test set
# The `build_test` method in `ASLdb` is similar to the `build_training` method already presented, but there are a few differences:
# - the object is type `SinglesData`
# - the internal dictionary keys are the index of the test word rather than the word itself
# - the getter methods are `get_all_sequences`, `get_all_Xlengths`, `get_item_sequences` and `get_item_Xlengths`

# %%
test_set = asl.build_test(features_ground)
print("Number of test set items: {}".format(test_set.num_items))
print("Number of test set sentences: {}".format(len(test_set.sentences_index)))
# Out:
# Number of test set items: 178
# Number of test set sentences: 40

# %% [markdown]
# <a id='part3_submission'></a>
# ### Recognizer Implementation Submission
# For the final project submission, students must implement a recognizer following guidance in the `my_recognizer.py` module.  Experiment with the four feature sets and the three model selection methods (that's 12 possible combinations). You can add and remove cells for experimentation or run the recognizers locally in some other way during your experiments, but retain the results for your discussion.  For submission, you will provide code cells of **only three** interesting combinations for your discussion (see questions below). At least one of these should produce a word error rate of less than 60%, i.e. WER < 0.60 .
#
# **Tip:** The hmmlearn library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
# TODO implement the recognize method in my_recognizer

from my_recognizer import recognize
from asl_utils import show_errors

# %%
# TODO Choose a feature set and model selector
import my_recognizer
reload(my_recognizer)
from my_recognizer import recognize
features = features_ground # change as needed
model_selector = SelectorConstant # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.6685393258426966
# Total correct: 59 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: *GO WRITE *ARRIVE                                             JOHN WRITE HOMEWORK
#     7: *SOMETHING-ONE *GO1 *IX CAN                                   JOHN CAN GO CAN
#    12: JOHN *HAVE *WHAT CAN                                          JOHN CAN GO CAN
#    21: JOHN *HOMEWORK *NEW *PREFER *CAR *CAR *FUTURE *EAT            JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: *FRANK *TELL *LOVE *TELL *LOVE                                JOHN LIKE IX IX IX
#    28: *FRANK *TELL *LOVE *TELL *LOVE                                JOHN LIKE IX IX IX
#    30: *SHOULD LIKE *GO *GO *GO                                      JOHN LIKE IX IX IX
#    36: *VISIT VEGETABLE *YESTERDAY *GIVE *MARY *MARY                 MARY VEGETABLE KNOW IX LIKE CORN1
#    40: *SUE *GIVE *CORN *VEGETABLE *GO                               JOHN IX THINK MARY LOVE
#    43: *FRANK *GO BUY HOUSE                                          JOHN MUST BUY HOUSE
#    50: *FRANK *SEE BUY CAR *SOMETHING-ONE                            FUTURE JOHN BUY CAR SHOULD
#    54: JOHN SHOULD *WHO BUY HOUSE                                    JOHN SHOULD NOT BUY HOUSE
#    57: *MARY *VISIT VISIT *VISIT                                     JOHN DECIDE VISIT MARY
#    67: *LIKE FUTURE NOT BUY HOUSE                                    JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *FINISH VISIT MARY                                       JOHN WILL VISIT MARY
#    74: *IX *VISIT *GO *GO                                            JOHN NOT VISIT MARY
#    77: *JOHN BLAME *LOVE                                             ANN BLAME MARY
#    84: *LOVE *ARRIVE *HOMEWORK BOOK                                  IX-1P FIND SOMETHING-ONE BOOK
#    89: *GIVE *GIVE GIVE *IX IX *ARRIVE *BOOK                         JOHN IX GIVE MAN IX NEW COAT
#    90: *SOMETHING-ONE *SOMETHING-ONE IX *IX WOMAN *COAT              JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: *FRANK GIVE *WOMAN *WOMAN WOMAN BOOK                          JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: *FRANK *VEGETABLE                                             JOHN LEG
#   107: *SHOULD *IX FRIEND *GO *JANA                                  JOHN POSS FRIEND HAVE CANDY
#   108: *GIVE *LOVE                                                   WOMAN ARRIVE
#   113: IX CAR *CAR *IX *IX                                           IX CAR BLUE SUE BUY
#   119: *PREFER *BUY1 IX *BLAME *IX                                   SUE BUY IX CAR BLUE
#   122: JOHN *GIVE1 *COAT                                             JOHN READ BOOK
#   139: *SHOULD *BUY1 *CAR *BLAME BOOK                                JOHN BUY WHAT YESTERDAY BOOK
#   142: *FRANK *STUDENT YESTERDAY *TEACHER BOOK                       JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE *MARY WHO                                                LOVE JOHN WHO
#   167: *MARY IX *VISIT *WOMAN *LOVE                                  JOHN IX SAY LOVE MARY
#   171: *VISIT *VISIT BLAME                                           JOHN MARY BLAME
#   174: *CAN *GIVE3 GIVE1 *APPLE *WHAT                                PEOPLE GROUP GIVE1 JANA TOY
#   181: *BLAME ARRIVE                                                 JOHN ARRIVE
#   184: *GIVE1 BOY *GIVE1 TEACHER APPLE                               ALL BOY GIVE TEACHER APPLE
#   189: *JANA *SOMETHING-ONE *YESTERDAY *WHAT                         JOHN GIVE GIRL BOX
#   193: JOHN *SOMETHING-ONE *YESTERDAY BOX                            JOHN GIVE GIRL BOX
#   199: *LOVE CHOCOLATE WHO                                           LIKE CHOCOLATE WHO
#   201: JOHN *GIVE *GIVE *LOVE *ARRIVE HOUSE                          JOHN TELL MARY IX-1P BUY HOUSE

# %%
features = features_norm # change as needed
model_selector = SelectorConstant # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.6235955056179775
# Total correct: 67 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: *MARY WRITE *ARRIVE                                           JOHN WRITE HOMEWORK
#     7: JOHN *NEW *JOHN CAN                                           JOHN CAN GO CAN
#    12: *SHOULD *HAVE *GO1 CAN                                        JOHN CAN GO CAN
#    21: *LIKE *NEW *HAVE *IX-1P *CAR *BLAME *CHICKEN *WRITE           JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: *IX LIKE *LIKE *LIKE IX                                       JOHN LIKE IX IX IX
#    28: *ANN LIKE *ANN *LIKE *ANN                                     JOHN LIKE IX IX IX
#    30: *SHOOT LIKE *LOVE *LIKE *MARY                                 JOHN LIKE IX IX IX
#    36: *LEAVE *NOT *YESTERDAY *VISIT LIKE *JOHN                      MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN *LEAVE *FUTURE1 *VEGETABLE LOVE                          JOHN IX THINK MARY LOVE
#    43: JOHN *SHOULD BUY HOUSE                                        JOHN MUST BUY HOUSE
#    50: *FRANK *SEE *ARRIVE CAR *CAR                                  FUTURE JOHN BUY CAR SHOULD
#    54: JOHN SHOULD *FUTURE *STUDENT HOUSE                            JOHN SHOULD NOT BUY HOUSE
#    57: *MARY *MARY *MARY MARY                                        JOHN DECIDE VISIT MARY
#    67: *IX-1P FUTURE *JOHN *ARRIVE HOUSE                             JOHN FUTURE NOT BUY HOUSE
#    71: JOHN WILL VISIT MARY                                          JOHN WILL VISIT MARY
#    74: *WOMAN *VISIT VISIT *FRANK                                    JOHN NOT VISIT MARY
#    77: *IX BLAME MARY                                                ANN BLAME MARY
#    84: *IX *ARRIVE *NEW BOOK                                         IX-1P FIND SOMETHING-ONE BOOK
#    89: *FUTURE *THROW *JOHN *JOHN *WOMAN *BOOK *BREAK-DOWN           JOHN IX GIVE MAN IX NEW COAT
#    90: *SELF *GIVE1 IX *IX WOMAN *CHOCOLATE                          JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *GIVE1 IX *IX WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: *WHO *SEE                                                     JOHN LEG
#   107: *TELL *IX *BOX *LIKE *JANA                                    JOHN POSS FRIEND HAVE CANDY
#   108: *LOVE *HOMEWORK                                               WOMAN ARRIVE
#   113: IX CAR *IX SUE *HAVE                                          IX CAR BLUE SUE BUY
#   119: *VEGETABLE *BUY1 IX CAR *GO                                   SUE BUY IX CAR BLUE
#   122: JOHN *HOUSE *COAT                                             JOHN READ BOOK
#   139: JOHN *BUY1 *CAR YESTERDAY BOOK                                JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BU
OHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: *IX NEW CAR *HOUSE                                            POSS NEW CAR BREAK-DOWN
#   105: JOHN *MARY                                                    JOHN LEG
#   107: *MARY POSS *VISIT *MARY *JOHN                                 JOHN POSS FRIEND HAVE CANDY
#   108: *IX *STUDENT                                                  WOMAN ARRIVE
#   113: *JOHN CAR *MARY *GIVE *BOOK                                   IX CAR BLUE SUE BUY
#   119: *IX *BUY1 IX CAR *WHO                                         SUE BUY IX CAR BLUE
#   122: JOHN *CAR BOOK                                                JOHN READ BOOK
#   139: JOHN *BOOK *TEACHER *JOHN *ARRIVE                             JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY *HOUSE WHAT BOOK                                     JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE *WHO *MARY                                               LOVE JOHN WHO
#   167: *MARY *SHOULD *WOMAN LOVE *HERE                               JOHN IX SAY LOVE MARY
#   171: *THINK *JOHN *ARRIVE                                          JOHN MARY BLAME
#   174: *CAR *JOHN GIVE1 *MARY *BLAME                                 PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN ARRIVE                                                   JOHN ARRIVE
#   184: *GIVE *GIVE1 *GIVE1 TEACHER *YESTERDAY                        ALL BOY GIVE TEACHER APPLE
#   189: JOHN GIVE GIRL *BOOK                                          JOHN GIVE GIRL BOX
#   193: JOHN *IX *HAVE BOX                                            JOHN GIVE GIRL BOX
#   199: *JOHN *ARRIVE *JOHN                                           LIKE CHOCOLATE WHO
#   201: JOHN *WHO *WHO *POSS *VISIT HOUSE                             JOHN TELL MARY IX-1P BUY HOUSE

# %% [markdown]
# **Question 3:**  Summarize the error results from three combinations of features and model selectors.  What was the "best" combination and why?  What additional information might we use to improve our WER?  For more insight on improving WER, take a look at the introduction to Part 4.
#
# **Answer 3:**

# %% [markdown]
# <a id='part3_test'></a>
# ### Recognizer Unit Tests
# Run the following unit tests as a sanity check on the defined recognizer.  The test simply looks for some valid values but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_recognizer import TestRecognize
suite = unittest.TestLoader().loadTestsFromModule(TestRecognize())
unittest.TextTestRunner().run(suite)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 45.606s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# <a id='part4_info'></a>
# ## PART 4: (OPTIONAL)  Improve the WER with Language Models
# We've squeezed just about as much as we can out of the model and still only get about 50% of the words right! Surely we can do better than that.  Probability to the rescue again in the form of [statistical language models (SLM)](https://en.wikipedia.org/wiki/Language_model).  The basic idea is that each word has some probability of occurrence within the set, and some probability that it is adjacent to specific other words. We can use that additional information to make better choices.
#
# ##### Additional reading and resources
# - [Introduction to N-grams (Stanford Jurafsky slides)](https://web.stanford.edu/class/cs124/lec/languagemodeling.pdf)
# - [Speech Recognition Techniques for a Sign Language Recognition System, Philippe Dreuw et al](https://www-i6.informatik.rwth-aachen.de/publications/download/154/Dreuw--2007.pdf) see the improved results of applying LM on *this* data!
# - [SLM data for *this* ASL dataset](ftp://wasserstoff.informatik.rwth-aachen.de/pub/rwth-boston-104/lm/)
#
# ##### Optional challenge
# The recognizer you implemented in Part 3 is equivalent to a "0-gram" SLM.  Improve the WER with the SLM data provided with the data set in the link above using "1-gram", "2-gram", and/or "3-gram" statistics. The `probabilities` data you've already calculated will be useful and can be turned into a pandas DataFrame if desired (see next cell).
# Good luck!  Share your results with the class!

# %%
# create a DataFrame of log likelihoods for the test word items
df_probs = pd.DataFrame(data=probabilities)
df_probs.head()
# Out:
#            ALL  ANN        APPLE      ARRIVE         BILL       BLAME  \
# 0 -3000.141152 -inf -2591.152582 -361.794643  -566.658480 -278.020154
# 1 -5761.285913 -inf -3714.701403 -216.456645 -4192.784860 -304.222562
# 2 -8946.664671 -inf -7856.787692 -440.330148 -5159.524585 -548.150083
# 3  -719.771460 -inf  -899.325442 -445.759697  -898.722874 -406.771645
# 4 -1338.629213 -inf  -636.919657 -113.764135 -1153.545135 -105.453065
#
#            BLUE        BOOK        BORROW         BOX     ...      \
# 0  -6983.956669 -564.106495  -6232.402381 -394.607946     ...
# 1  -5500.257251 -182.500921  -4528.093860 -419.142391     ...
# 2 -12251.487517 -673.694764  -4068.373674 -778.430893     ...
# 3   -524.075990 -738.466702 -54108.019784 -519.582164     ...
# 4   -257.843503 -147.162646  -2208.462718 -106.164780     ...
#
#      VIDEOTAPE       VISIT         WANT        WHAT         WHO          WILL  \
# 0  -500.151483 -275.272596 -2252.126493 -390.718063 -226.425267  -7592.959725
# 1  -211.205575 -330.033225 -1816.520067 -316.418142 -261.906706 -10987.184078
# 2  -675.611839 -613.528302 -3130.139895 -660.128653 -550.734420 -17612.725279
# 3 -1271.014080 -286.618478 -5098.809288 -549.470392 -573.390633 -23860.442735
# 4  -258.577899 -103.911399  -642.171734 -101.390844 -210.671529 -11006.633435
#
#         WOMAN         WONT        WRITE   YESTERDAY
# 0 -849.845829  -890.211875  -416.446148 -387.595600
# 1 -378.273831  -520.088361  -170.360172 -456.890372
# 2 -897.344119 -1144.800689 -1023.484384 -754.424381
# 3 -413.205192  -650.195190 -3433.649437 -506.820853
# 4 -242.561860  -706.817196 -1201.459971 -144.498496
#
# [5 rows x 112 columns]

# %%
test_set = asl.build_test(features)

# %%
#test_set.df.head()
#test_set.wordlist
test_set.sentences_index
#len(test_set._data)
#len(test_set.wordlist)
# Out:
# {2: [0, 1, 2],
#  7: [3, 4, 5, 6],
#  12: [7, 8, 9, 10],
#  21: [11, 12, 13, 14, 15, 16, 17, 18],
#  25: [19, 20, 21, 22, 23],
#  28: [24, 25, 26, 27, 28],
#  30: [29, 30, 31, 32, 33],
#  36: [34, 35, 36, 37, 38, 39],
#  40: [40, 41, 42, 43, 44],
#  43: [45, 46, 47, 48],
#  50: [49, 50, 51, 52, 53],
#  54: [54, 55, 56, 57, 58],
#  57: [59, 60, 61, 62],
#  67: [63, 64, 65, 66, 67],
#  71: [68, 69, 70, 71],
#  74: [72, 73, 74, 75],
#  77: [76, 77, 78],
#  84: [79, 80, 81, 82],
#  89: [83, 84, 85, 86, 87, 88, 89],
#  90: [90, 91, 92, 93, 94, 95],
#  92: [96, 97, 98, 99, 100, 101],
#  100: [102, 103, 104, 105],
#  105: [106, 107],
#  107: [108, 109, 110, 111, 112],
#  108: [113, 114],
#  113: [115, 116, 117, 118, 119],
#  119: [120, 121, 122, 123, 124],
#  122: [125, 126, 127],
#  139: [128, 129, 130, 131, 132],
#  142: [133, 134, 135, 136, 137],
#  158: [138, 139, 140],
#  167: [141, 142, 143, 144, 145],
#  171: [146, 147, 148],
#  174: [149, 150, 151, 152, 153],
#  181: [154, 155],
#  184: [156, 157, 158, 159, 160],
#  189: [161, 162, 163, 164],
#  193: [165, 166, 167, 168],
#  199: [169, 170, 171],
#  201: [172, 173, 174, 175, 176, 177]}

# %%
import requests
# !pip install arpa
# Out:
# Requirement already satisfied: arpa in /home/jota/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: enum34 in /home/jota/anaconda3/lib/python3.6/site-packages (from arpa)

# %%
import arpa
models = arpa.loadf("devel-lm-M3.sri.lm")
lm = models[0]

# %%
print(lm)
# Out:
# <arpa.models.simple.ARPAModelSimple object at 0xa6ac1d6c>

# %%
#lm.log_s("GIVE GIRL",sos=False, eos=False)
lm.log_s("GIVE GIRL", eos=False)
# Out:
# -4.0687414000000075

# %%
from imp import reload
import arpa
features = features_delta_norm_polar # change as needed
model_selector = SelectorDIC # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
models_arpa = arpa.loadf("devel-lm-M3.sri.lm")
model_arpa = models_arpa[0]

# %%
import my_recognizer
reload(my_recognizer)
from my_recognizer import recognize_gram_1
guesses = recognize_gram_1(models, test_set,model_arpa,C=7)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.550561797752809
# Total correct: 80 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *IX HOMEWORK                                             JOHN WRITE HOMEWORK
#     7: JOHN *VISIT GO *ARRIVE                                        JOHN CAN GO CAN
#    12: JOHN *BOX *FUTURE CAN                                         JOHN CAN GO CAN
#    21: JOHN FISH *MARY *MARY *HOUSE *GO *MARY *MARY                  JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX
#    28: JOHN *MARY IX IX IX                                           JOHN LIKE IX IX IX
#    30: JOHN *MARY *MARY *GIVE IX                                     JOHN LIKE IX IX IX
#    36: *JOHN *JOHN *GIVE IX *JOHN *IX                                MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN IX *WHO *WHO *MARY                                       JOHN IX THINK MARY LOVE
#    43: JOHN *IX BUY HOUSE                                            JOHN MUST BUY HOUSE
#    50: *JOHN *IX BUY CAR *MARY                                       FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *MARY *JOHN BUY HOUSE                                    JOHN SHOULD NOT BUY HOUSE
#    57: *MARY *MARY VISIT *IX                                         JOHN DECIDE VISIT MARY
#    67: JOHN *IX *IX BUY HOUSE                                        JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *IX *GO MARY                                             JOHN WILL VISIT MARY
#    74: JOHN *IX VISIT *IX                                            JOHN NOT VISIT MARY
#    77: *JOHN *ARRIVE MARY                                            ANN BLAME MARY
#    84: *JOHN *GIVE1 *IX BOOK                                         IX-1P FIND SOMETHING-ONE BOOK
#    89: JOHN IX GIVE *IX *GIVE *WHAT *CAN                             JOHN IX GIVE MAN IX NEW COAT
#    90: JOHN GIVE IX *GIVE WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *IX IX *IX *IX *JOHN                                     JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: *JOHN NEW CAR *HOUSE                                          POSS NEW CAR BREAK-DOWN
#   105: JOHN *IX                                                      JOHN LEG
#   107: JOHN POSS *VISIT *MARY *JOHN                                  JOHN POSS FRIEND HAVE CANDY
#   108: *IX *STUDENT                                                  WOMAN ARRIVE
#   113: *JOHN CAR *MARY *GIVE *BOOK                                   IX CAR BLUE SUE BUY
#   119: *JOHN *BUY1 IX CAR *WHO                                       SUE BUY IX CAR BLUE
#   122: JOHN *CAR BOOK                                                JOHN READ BOOK
#   139: JOHN *BOOK *CAR *JOHN *ARRIVE                                 JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY *IX WHAT BOOK                                        JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE *WHO *MARY                                               LOVE JOHN WHO
#   167: JOHN *SHOULD *IX LOVE MARY                                    JOHN IX SAY LOVE MARY
#   171: JOHN *JOHN *ARRIVE                                            JOHN MARY BLAME
#   174: *CAR *JOHN GIVE1 *IX *BLAME                                   PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN ARRIVE                                                   JOHN ARRIVE
#   184: *IX *IX *GIVE1 TEACHER *IX                                    ALL BOY GIVE TEACHER APPLE
#   189: JOHN GIVE GIRL *BOOK                                          JOHN GIVE GIRL BOX
#   193: JOHN *IX *HAVE BOX                                            JOHN GIVE GIRL BOX
#   199: *JOHN *ARRIVE *JOHN                                           LIKE CHOCOLATE WHO
#   201: JOHN *IX *WHO *POSS *VISIT HOUSE                              JOHN TELL MARY IX-1P BUY HOUSE

# %%
import my_recognizer
reload(my_recognizer)
import copy
from my_recognizer import recognize_gram_2
l_test=copy.copy(test_set)
item=list(test_set.sentences_index.items())
l_test.sentences_index={}
for n in range(1):
    k,v=item[n]
    l_test.sentences_index[k]=v
                                                
guesses = recognize_gram_2(models, l_test,model_arpa,C=7)
guesses = guesses  + [1] * (l_test.num_items - len(guesses))
show_errors(guesses, l_test)
# Out:
# ('JOHN', 'JOHN') -2.2016244--JOHN JOHN
# ('JOHN', 'WRITE') -2.5262744999999995--JOHN WRITE
# ('JOHN', 'HOMEWORK') -3.0891763999999995--JOHN HOMEWORK
# ('JOHN', 'IX-1P') -2.8929284000000024--JOHN IX-1P
# ('JOHN', 'SEE') -1.4914598999999953--JOHN SEE
# ('JOHN', 'YESTERDAY') -2.3415694999999914--JOHN YESTERDAY
# ('JOHN', 'IX') -1.5011738999999977--JOHN IX
# ('JOHN', 'LOVE') -1.420786800000002--JOHN LOVE
# ('JOHN', 'MARY') -1.8599169000000018--JOHN MARY
# ('JOHN', 'CAN') -1.4717488999999944--JOHN CAN
# ('JOHN', 'GO') -1.4045888999999931--JOHN GO
# ('JOHN', 'GO1')-<class 'KeyError'>-JOHN GO1
# ('JOHN', 'FUTURE') -1.3033539000000047--JOHN FUTURE
# ('JOHN', 'GO2')-<class 'KeyError'>-JOHN GO2
# ('JOHN', 'PARTY') -3.0891763999999995--JOHN PARTY
# ('JOHN', 'FUTURE1')-<class 'KeyError'>-JOHN FUTURE1
# ('JOHN', 'HIT') -3.0891763999999995--JOHN HIT
# ('JOHN', 'BLAME') -2.8929284000000024--JOHN BLAME
# ('JOHN', 'FRED') -3.0891763999999995--JOHN FRED
# ('JOHN', 'FISH') -2.5262744999999995--JOHN FISH
# ('JOHN', 'WONT') -2.998661400000003--JOHN WONT
# ('JOHN', 'EAT') -2.998661400000003--JOHN EAT
# ('JOHN', 'BUT') -3.0891763999999995--JOHN BUT
# ('JOHN', 'CHICKEN') -3.0891763999999995--JOHN CHICKEN
# ('JOHN', 'COAT') -3.0891763999999995--JOHN COAT
# ('JOHN', 'WOMAN') -2.7361594000000053--JOHN WOMAN
# ('JOHN', 'GIVE1')-<class 'KeyError'>-JOHN GIVE1
# ('JOHN', 'HAVE') -2.8929284000000024--JOHN HAVE
# ('JOHN', 'FRANK') -2.998661400000003--JOHN FRANK
# ('JOHN', 'BREAK-DOWN') -3.0891763999999995--JOHN BREAK-DOWN
# ('JOHN', 'SEARCH-FOR') -2.5262744999999995--JOHN SEARCH-FOR
# ('JOHN', 'WHO') -2.102812499999999--JOHN WHO
# ('JOHN', 'WHAT') -2.1308533999999923--JOHN WHAT
# ('JOHN', 'LEG') -3.0891763999999995--JOHN LEG
# ('JOHN', 'FRIEND') -3.0891763999999995--JOHN FRIEND
# ('JOHN', 'CANDY') -3.0891763999999995--JOHN CANDY
# ('JOHN', 'BLUE') -3.0891763999999995--JOHN BLUE
# ('JOHN', 'SUE') -3.0891763999999995--JOHN SUE
# ('JOHN', 'BUY1')-<class 'KeyError'>-JOHN BUY1
# ('JOHN', 'STOLEN') -3.0891763999999995--JOHN STOLEN
# ('JOHN', 'OLD') -3.0891763999999995--JOHN OLD
# ('JOHN', 'STUDENT') -3.0891763999999995--JOHN STUDENT
# ('JOHN', 'VIDEOTAPE') -2.998661400000003--JOHN VIDEOTAPE
# ('JOHN', 'BORROW') -3.0891763999999995--JOHN BORROW
# ('JOHN', 'MOTHER') -2.4632074999999958--JOHN MOTHER
# ('JOHN', 'POTATO') -3.0891763999999995--JOHN POTATO
# ('JOHN', 'TELL') -2.998661400000003--JOHN TELL
# ('JOHN', 'BILL') -2.998661400000003--JOHN BILL
# ('JOHN', 'THROW') -3.0891763999999995--JOHN THROW
# ('JOHN', 'APPLE') -2.998661400000003--JOHN APPLE
# ('JOHN', 'NAME') -3.0891763999999995--JOHN NAME
# ('JOHN', 'SHOOT') -3.0891763999999995--JOHN SHOOT
# ('JOHN', 'SAY-1P') -3.0891763999999995--JOHN SAY-1P
# ('JOHN', 'SELF') -3.0891763999999995--JOHN SELF
# ('JOHN', 'GROUP') -3.0891763999999995--JOHN GROUP
# ('JOHN', 'JANA') -3.0891763999999995--JOHN JANA
# ('JOHN', 'TOY1')-<class 'KeyError'>-JOHN TOY1
# ('JOHN', 'MANY') -3.0891763999999995--JOHN MANY
# ('JOHN', 'TOY') -3.0891763999999995--JOHN TOY
# ('JOHN', 'ALL') -3.0891763999999995--JOHN ALL
# ('JOHN', 'BOY') -2.998661400000003--JOHN BOY
# ('JOHN', 'TEACHER') -2.998661400000003--JOHN TEACHER
# ('JOHN', 'GIRL') -2.998661400000003--JOHN GIRL
# ('JOHN', 'BOX') -2.4995784999999984--JOHN BOX
# ('JOHN', 'GIVE2')-<class 'KeyError'>-JOHN GIVE2
# ('JOHN', 'GIVE3')-<class 'KeyError'>-JOHN GIVE3
# ('JOHN', 'GET') -3.0891763999999995--JOHN GET
# ('JOHN', 'PUTASIDE') -3.0891763999999995--JOHN PUTASIDE
# ('WRITE', 'JOHN') -4.863139500000003--WRITE JOHN
# ('WRITE', 'WRITE') -5.750691500000002--WRITE WRITE
# ('WRITE', 'HOMEWORK') -3.8304753999999974--WRITE HOMEWORK
# ('WRITE', 'IX-1P') -5.554443499999991--WRITE IX-1P
# ('WRITE', 'SEE') -5.554443499999991--WRITE SEE
# ('WRITE', 'YESTERDAY') -5.282729500000002--WRITE YESTERDAY
# ('WRITE', 'IX') -4.704034499999992--WRITE IX
# ('WRITE', 'LOVE') -5.397674499999994--WRITE LOVE
# ('WRITE', 'MARY') -4.863139500000003--WRITE MARY
# ('WRITE', 'CAN') -5.397674499999994--WRITE CAN
# ('WRITE', 'GO') -5.282729500000002--WRITE GO
# ('WRITE', 'GO1')-<class 'KeyError'>-WRITE GO1
# ('WRITE', 'FUTURE') -5.282729500000002--WRITE FUTURE
# ('WRITE', 'GO2')-<class 'KeyError'>-WRITE GO2
# ('WRITE', 'PARTY') -5.750691500000002--WRITE PARTY
# ('WRITE', 'FUTURE1')-<class 'KeyError'>-WRITE FUTURE1
# ('WRITE', 'HIT') -5.750691500000002--WRITE HIT
# ('WRITE', 'BLAME') -5.554443499999991--WRITE BLAME
# ('WRITE', 'FRED') -5.750691500000002--WRITE FRED
# ('WRITE', 'FISH') -5.750691500000002--WRITE FISH
# ('WRITE', 'WONT') -5.6601764999999915--WRITE WONT
# ('WRITE', 'EAT') -5.6601764999999915--WRITE EAT
# ('WRITE', 'BUT') -5.750691500000002--WRITE BUT
# ('WRITE', 'CHICKEN') -5.750691500000002--WRITE CHICKEN
# ('WRITE', 'VEGETABLE') -5.554443499999991--WRITE VEGETABLE
# ('WRITE', 'CHINA') -5.750691500000002--WRITE CHINA
# ('WRITE', 'PEOPLE') -5.554443499999991--WRITE PEOPLE
# ('WRITE', 'PREFER') -5.397674499999994--WRITE PREFER
# ('WRITE', 'BROCCOLI') -5.750691500000002--WRITE BROCCOLI
# ('WRITE', 'LIKE') -5.554443499999991--WRITE LIKE
# ('WRITE', 'LEAVE') -5.750691500000002--WRITE LEAVE
# ('WRITE', 'SAY') -5.6601764999999915--WRITE SAY
# ('WRITE', 'BUY') -5.116867499999998--WRITE BUY
# ('WRITE', 'HOUSE') -5.6601764999999915--WRITE HOUSE
# ('WRITE', 'KNOW') -5.6601764999999915--WRITE KNOW
# ('WRITE', 'CORN') -5.6601764999999915--WRITE CORN
# ('WRITE', 'CORN1')-<class 'KeyError'>-WRITE CORN1
# ('WRITE', 'THINK') -5.750691500000002--WRITE THINK
# ('WRITE', 'NOT') -5.397674499999994--WRITE NOT
# ('WRITE', 'PAST') -5.750691500000002--WRITE PAST
# ('WRITE', 'LIVE') -5.750691500000002--WRITE LIVE
# ('WRITE', 'CHICAGO') -5.750691500000002--WRITE CHICAGO
# ('WRITE', 'CAR') -5.191928500000003--WRITE CAR
# ('WRITE', 'SHOULD') -5.554443499999991--WRITE SHOULD
# ('WRITE', 'DECIDE') -5.750691500000002--WRITE DECIDE
# ('WRITE', 'VISIT') -5.191928500000003--WRITE VISIT
# ('WRITE', 'MOVIE') -5.750691500000002--WRITE MOVIE
# ('WRITE', 'WANT') -5.750691500000002--WRITE WANT
# ('WRITE', 'SELL') -5.6601764999999915--WRITE SELL
# ('WRITE', 'TOMORROW') -5.750691500000002--WRITE TOMORROW
# ('WRITE', 'NEXT-WEEK') -5.750691500000002--WRITE NEXT-WEEK
# ('WRITE', 'NEW-YORK') -5.750691500000002--WRITE NEW-YORK
# ('WRITE', 'LAST-WEEK') -5.750691500000002--WRITE LAST-WEEK
# ('WRITE', 'WILL') -5.750691500000002--WRITE WILL
# ('WRITE', 'FINISH') -5.6601764999999915--WRITE FINISH
# ('WRITE', 'ANN') -5.750691500000002--WRITE ANN
# ('WRITE', 'READ') -5.6601764999999915--WRITE READ
# ('WRITE', 'BOOK') -5.052888499999995--WRITE BOOK
# ('WRITE', 'CHOCOLATE') -5.750691500000002--WRITE CHOCOLATE
# ('WRITE', 'FIND') -5.750691500000002--WRITE FIND
# ('WRITE', 'SOMETHING-ONE') -5.282729500000002--WRITE SOMETHING-ONE
# ('WRITE', 'POSS') -5.191928500000003--WRITE POSS
# ('WRITE', 'BROTHER') -5.6601764999999915--WRITE BROTHER
# ('WRITE', 'ARRIVE') -5.052888499999995--WRITE ARRIVE
# ('WRITE', 'HERE') -5.750691500000002--WRITE HERE
# ('WRITE', 'GIVE') -5.052888499999995--WRITE GIVE
# ('WRITE', 'MAN') -5.750691500000002--WRITE MAN
# ('WRITE', 'NEW') -5.6601764999999915--WRITE NEW
# ('WRITE', 'COAT') -5.750691500000002--WRITE COAT
# ('WRITE', 'WOMAN') -5.397674499999994--WRITE WOMAN
# ('WRITE', 'GIVE1')-<class 'KeyError'>-WRITE GIVE1
# ('WRITE', 'HAVE') -5.554443499999991--WRITE HAVE
# ('WRITE', 'FRANK') -5.6601764999999915--WRITE FRANK
# ('WRITE', 'BREAK-DOWN') -5.750691500000002--WRITE BREAK-DOWN
# ('WRITE', 'SEARCH-FOR') -5.750691500000002--WRITE SEARCH-FOR
# ('WRITE', 'WHO') -4.9033795--WRITE WHO
# ('WRITE', 'WHAT') -4.792368499999995--WRITE WHAT
# ('WRITE', 'LEG') -5.750691500000002--WRITE LEG
# ('WRITE', 'FRIEND') -5.750691500000002--WRITE FRIEND
# ('WRITE', 'CANDY') -5.750691500000002--WRITE CANDY
# ('WRITE', 'BLUE') -5.750691500000002--WRITE BLUE
# ('WRITE', 'SUE') -5.750691500000002--WRITE SUE
# ('WRITE', 'BUY1')-<class 'KeyError'>-WRITE BUY1
# ('WRITE', 'STOLEN') -5.750691500000002--WRITE STOLEN
# ('WRITE', 'OLD') -5.750691500000002--WRITE OLD
# ('WRITE', 'STUDENT') -5.750691500000002--WRITE STUDENT
# ('WRITE', 'VIDEOTAPE') -5.6601764999999915--WRITE VIDEOTAPE
# ('WRITE', 'BORROW') -5.750691500000002--WRITE BORROW
# ('WRITE', 'MOTHER') -5.554443499999991--WRITE MOTHER
# ('WRITE', 'POTATO') -5.750691500000002--WRITE POTATO
# ('WRITE', 'TELL') -5.6601764999999915--WRITE TELL
# ('WRITE', 'BILL') -5.6601764999999915--WRITE BILL
# ('WRITE', 'THROW') -5.750691500000002--WRITE THROW
# ('WRITE', 'APPLE') -5.6601764999999915--WRITE APPLE
# ('WRITE', 'NAME') -5.750691500000002--WRITE NAME
# ('WRITE', 'SHOOT') -5.750691500000002--WRITE SHOOT
# ('WRITE', 'SAY-1P') -5.750691500000002--WRITE SAY-1P
# ('WRITE', 'SELF') -5.750691500000002--WRITE SELF
# ('WRITE', 'GROUP') -5.750691500000002--WRITE GROUP
# ('WRITE', 'JANA') -5.750691500000002--WRITE JANA
# ('WRITE', 'TOY1')-<class 'KeyError'>-WRITE TOY1
# ('WRITE', 'MANY') -5.750691500000002--WRITE MANY
# ('WRITE', 'TOY') -5.750691500000002--WRITE TOY
# ('WRITE', 'ALL') -5.750691500000002--WRITE ALL
# ('WRITE', 'BOY') -5.6601764999999915--WRITE BOY
# ('WRITE', 'TEACHER') -5.6601764999999915--WRITE TEACHER
# ('WRITE', 'GIRL') -5.6601764999999915--WRITE GIRL
# ('WRITE', 'BOX') -5.6601764999999915--WRITE BOX
# ('WRITE', 'GIVE2')-<class 'KeyError'>-WRITE GIVE2
# ('WRITE', 'GIVE3')-<class 'KeyError'>-WRITE GIVE3
# ('WRITE', 'GET') -5.750691500000002--WRITE GET
# ('WRITE', 'PUTASIDE') -5.750691500000002--WRITE PUTASIDE
# ('HOMEWORK', 'JOHN') -4.863139500000003--HOMEWORK JOHN
# ('HOMEWORK', 'WRITE') -5.750691500000002--HOMEWORK WRITE
# ('HOMEWORK', 'HOMEWORK') -5.750691500000002--HOMEWORK HOMEWORK
# ('HOMEWORK', 'IX-1P') -5.554443499999991--HOMEWORK IX-1P
# ('HOMEWORK', 'SEE') -5.554443499999991--HOMEWORK SEE
# ('HOMEWORK', 'YESTERDAY') -5.282729500000002--HOMEWORK YESTERDAY
# ('HOMEWORK', 'IX') -4.704034499999992--HOMEWORK IX
# ('HOMEWORK', 'LOVE') -5.397674499999994--HOMEWORK LOVE
# ('HOMEWORK', 'MARY') -4.863139500000003--HOMEWORK MARY
# ('HOMEWORK', 'CAN') -5.397674499999994--HOMEWORK CAN
# ('HOMEWORK', 'GO') -5.282729500000002--HOMEWORK GO
# ('HOMEWORK', 'GO1')-<class 'KeyError'>-HOMEWORK GO1
# ('HOMEWORK', 'FUTURE') -5.282729500000002--HOMEWORK FUTURE
# ('HOMEWORK', 'GO2')-<class 'KeyError'>-HOMEWORK GO2
# ('HOMEWORK', 'PARTY') -5.750691500000002--HOMEWORK PARTY
# ('HOMEWORK', 'FUTURE1')-<class 'KeyError'>-HOMEWORK FUTURE1
# ('HOMEWORK', 'HIT') -5.750691500000002--HOMEWORK HIT
# ('HOMEWORK', 'BLAME') -5.554443499999991--HOMEWORK BLAME
# ('HOMEWORK', 'FRED') -5.750691500000002--HOMEWORK FRED
# ('HOMEWORK', 'FISH') -5.750691500000002--HOMEWORK FISH
# ('HOMEWORK', 'WONT') -5.6601764999999915--HOMEWORK WONT
# ('HOMEWORK', 'EAT') -5.6601764999999915--HOMEWORK EAT
# ('HOMEWORK', 'BUT') -5.750691500000002--HOMEWORK BUT
# ('HOMEWORK', 'CHICKEN') -5.750691500000002--HOMEWORK CHICKEN
# ('HOMEWORK', 'VEGETABLE') -5.554443499999991--HOMEWORK VEGETABLE
# ('HOMEWORK', 'CHINA') -5.750691500000002--HOMEWORK CHINA
# ('HOMEWORK', 'PEOPLE') -5.554443499999991--HOMEWORK PEOPLE
# ('HOMEWORK', 'PREFER') -5.397674499999994--HOMEWORK PREFER
# ('HOMEWORK', 'BROCCOLI') -5.750691500000002--HOMEWORK BROCCOLI
# ('HOMEWORK', 'LIKE') -5.554443499999991--HOMEWORK LIKE
# ('HOMEWORK', 'LEAVE') -5.750691500000002--HOMEWORK LEAVE
# ('HOMEWORK', 'SAY') -5.6601764999999915--HOMEWORK SAY
# ('HOMEWORK', 'BUY') -5.116867499999998--HOMEWORK BUY
# ('HOMEWORK', 'HOUSE') -5.6601764999999915--HOMEWORK HOUSE
# ('HOMEWORK', 'KNOW') -5.6601764999999915--HOMEWORK KNOW
# ('HOMEWORK', 'CORN') -5.6601764999999915--HOMEWORK CORN
# ('HOMEWORK', 'CORN1')-<class 'KeyError'>-HOMEWORK CORN1
# ('HOMEWORK', 'THINK') -5.750691500000002--HOMEWORK THINK
# ('HOMEWORK', 'NOT') -5.397674499999994--HOMEWORK NOT
# ('HOMEWORK', 'PAST') -5.750691500000002--HOMEWORK PAST
# ('HOMEWORK', 'LIVE') -5.750691500000002--HOMEWORK LIVE
# ('HOMEWORK', 'CHICAGO') -5.750691500000002--HOMEWORK CHICAGO
# ('HOMEWORK', 'CAR') -5.191928500000003--HOMEWORK CAR
# ('HOMEWORK', 'SHOULD') -5.554443499999991--HOMEWORK SHOULD
# ('HOMEWORK', 'DECIDE') -5.750691500000002--HOMEWORK DECIDE
# ('HOMEWORK', 'VISIT') -5.191928500000003--HOMEWORK VISIT
# ('HOMEWORK', 'MOVIE') -5.750691500000002--HOMEWORK MOVIE
# ('HOMEWORK', 'WANT') -5.750691500000002--HOMEWORK WANT
# ('HOMEWORK', 'SELL') -5.6601764999999915--HOMEWORK SELL
# ('HOMEWORK', 'TOMORROW') -5.750691500000002--HOMEWORK TOMORROW
# ('HOMEWORK', 'NEXT-WEEK') -5.750691500000002--HOMEWORK NEXT-WEEK
# ('HOMEWORK', 'NEW-YORK') -5.750691500000002--HOMEWORK NEW-YORK
# ('HOMEWORK', 'LAST-WEEK') -5.750691500000002--HOMEWORK LAST-WEEK
# ('HOMEWORK', 'WILL') -5.750691500000002--HOMEWORK WILL
# ('HOMEWORK', 'FINISH') -5.6601764999999915--HOMEWORK FINISH
# ('HOMEWORK', 'ANN') -5.750691500000002--HOMEWORK ANN
# ('HOMEWORK', 'READ') -5.6601764999999915--HOMEWORK READ
# ('HOMEWORK', 'BOOK') -5.052888499999995--HOMEWORK BOOK
# ('HOMEWORK', 'CHOCOLATE') -5.750691500000002--HOMEWORK CHOCOLATE
# ('HOMEWORK', 'FIND') -5.750691500000002--HOMEWORK FIND
# ('HOMEWORK', 'SOMETHING-ONE') -5.282729500000002--HOMEWORK SOMETHING-ONE
# ('HOMEWORK', 'POSS') -5.191928500000003--HOMEWORK POSS
# ('HOMEWORK', 'BROTHER') -5.6601764999999915--HOMEWORK BROTHER
# ('HOMEWORK', 'ARRIVE') -5.052888499999995--HOMEWORK ARRIVE
# ('HOMEWORK', 'HERE') -5.750691500000002--HOMEWORK HERE
# ('HOMEWORK', 'GIVE') -5.052888499999995--HOMEWORK GIVE
# ('HOMEWORK', 'MAN') -5.750691500000002--HOMEWORK MAN
# ('HOMEWORK', 'NEW') -5.6601764999999915--HOMEWORK NEW
# ('HOMEWORK', 'COAT') -5.750691500000002--HOMEWORK COAT
# ('HOMEWORK', 'WOMAN') -5.397674499999994--HOMEWORK WOMAN
# ('HOMEWORK', 'GIVE1')-<class 'KeyError'>-HOMEWORK GIVE1
# ('HOMEWORK', 'HAVE') -5.554443499999991--HOMEWORK HAVE
# ('HOMEWORK', 'FRANK') -5.6601764999999915--HOMEWORK FRANK
# ('HOMEWORK', 'BREAK-DOWN') -5.750691500000002--HOMEWORK BREAK-DOWN
# ('HOMEWORK', 'SEARCH-FOR') -5.750691500000002--HOMEWORK SEARCH-FOR
# ('HOMEWORK', 'WHO') -4.9033795--HOMEWORK WHO
# ('HOMEWORK', 'WHAT') -4.792368499999995--HOMEWORK WHAT
# ('HOMEWORK', 'LEG') -5.750691500000002--HOMEWORK LEG
# ('HOMEWORK', 'FRIEND') -5.750691500000002--HOMEWORK FRIEND
# ('HOMEWORK', 'CANDY') -5.750691500000002--HOMEWORK CANDY
# ('HOMEWORK', 'BLUE') -5.750691500000002--HOMEWORK BLUE
# ('HOMEWORK', 'SUE') -5.750691500000002--HOMEWORK SUE
# ('HOMEWORK', 'BUY1')-<class 'KeyError'>-HOMEWORK BUY1
# ('HOMEWORK', 'STOLEN') -5.750691500000002--HOMEWORK STOLEN
# ('HOMEWORK', 'OLD') -5.750691500000002--HOMEWORK OLD
# ('HOMEWORK', 'STUDENT') -5.750691500000002--HOMEWORK STUDENT
# ('HOMEWORK', 'VIDEOTAPE') -5.6601764999999915--HOMEWORK VIDEOTAPE
# ('HOMEWORK', 'BORROW') -5.750691500000002--HOMEWORK BORROW
# ('HOMEWORK', 'MOTHER') -5.554443499999991--HOMEWORK MOTHER
# ('HOMEWORK', 'POTATO') -5.750691500000002--HOMEWORK POTATO
# ('HOMEWORK', 'TELL') -5.6601764999999915--HOMEWORK TELL
# ('HOMEWORK', 'BILL') -5.6601764999999915--HOMEWORK BILL
# ('HOMEWORK', 'THROW') -5.750691500000002--HOMEWORK THROW
# ('HOMEWORK', 'APPLE') -5.6601764999999915--HOMEWORK APPLE
# ('HOMEWORK', 'NAME') -5.750691500000002--HOMEWORK NAME
# ('HOMEWORK', 'SHOOT') -5.750691500000002--HOMEWORK SHOOT
# ('HOMEWORK', 'SAY-1P') -5.750691500000002--HOMEWORK SAY-1P
# ('HOMEWORK', 'SELF') -5.750691500000002--HOMEWORK SELF
# ('HOMEWORK', 'GROUP') -5.750691500000002--HOMEWORK GROUP
# ('HOMEWORK', 'JANA') -5.750691500000002--HOMEWORK JANA
# ('HOMEWORK', 'TOY1')-<class 'KeyError'>-HOMEWORK TOY1
# ('HOMEWORK', 'MANY') -5.750691500000002--HOMEWORK MANY
# ('HOMEWORK', 'TOY') -5.750691500000002--HOMEWORK TOY
# ('HOMEWORK', 'ALL') -5.750691500000002--HOMEWORK ALL
# ('HOMEWORK', 'BOY') -5.6601764999999915--HOMEWORK BOY
# ('HOMEWORK', 'TEACHER') -5.6601764999999915--HOMEWORK TEACHER
# ('HOMEWORK', 'GIRL') -5.6601764999999915--HOMEWORK GIRL
# ('HOMEWORK', 'BOX') -5.6601764999999915--HOMEWORK BOX
# ('HOMEWORK', 'GIVE2')-<class 'KeyError'>-HOMEWORK GIVE2
# ('HOMEWORK', 'GIVE3')-<class 'KeyError'>-HOMEWORK GIVE3
# ('HOMEWORK', 'GET') -5.750691500000002--HOMEWORK GET
# ('HOMEWORK', 'PUTASIDE') -5.750691500000002--HOMEWORK PUTASIDE
# ('IX-1P', 'JOHN') -4.235561100000012--IX-1P JOHN
# ('IX-1P', 'WRITE') -5.123113100000012--IX-1P WRITE
# ('IX-1P', 'HOMEWORK') -5.123113100000012--IX-1P HOMEWORK
# ('IX-1P', 'IX-1P') -4.9268651000000006--IX-1P IX-1P
# ('IX-1P', 'SEE') -3.7782160000000005--IX-1P SEE
# ('IX-1P', 'YESTERDAY') -4.655151100000012--IX-1P YESTERDAY
# ('IX-1P', 'IX') -4.0764561000000015--IX-1P IX
# ('IX-1P', 'LOVE') -4.7700961000000035--IX-1P LOVE
# ('IX-1P', 'MARY') -4.235561100000012--IX-1P MARY
# ('IX-1P', 'CAN') -4.7700961000000035--IX-1P CAN
# ('IX-1P', 'GO') -4.655151100000012--IX-1P GO
# ('IX-1P', 'GO1')-<class 'KeyError'>-IX-1P GO1
# ('IX-1P', 'FUTURE') -4.655151100000012--IX-1P FUTURE
# ('IX-1P', 'GO2')-<class 'KeyError'>-IX-1P GO2
# ('IX-1P', 'PARTY') -5.123113100000012--IX-1P PARTY
# ('IX-1P', 'FUTURE1')-<class 'KeyError'>-IX-1P FUTURE1
# ('IX-1P', 'HIT') -5.123113100000012--IX-1P HIT
# ('IX-1P', 'BLAME') -4.9268651000000006--IX-1P BLAME
# ('IX-1P', 'FRED') -5.123113100000012--IX-1P FRED
# ('IX-1P', 'FISH') -5.123113100000012--IX-1P FISH
# ('IX-1P', 'WONT') -5.032598100000001--IX-1P WONT
# ('IX-1P', 'EAT') -5.032598100000001--IX-1P EAT
# ('IX-1P', 'BUT') -5.123113100000012--IX-1P BUT
# ('IX-1P', 'CHICKEN') -5.123113100000012--IX-1P CHICKEN
# ('IX-1P', 'VEGETABLE') -4.9268651000000006--IX-1P VEGETABLE
# ('IX-1P', 'CHINA') -5.123113100000012--IX-1P CHINA
# ('IX-1P', 'PEOPLE') -4.9268651000000006--IX-1P PEOPLE
# ('YESTERDAY', 'GIRL') -5.1922143999999975--YESTERDAY GIRL
# ('YESTERDAY', 'BOX') -5.1922143999999975--YESTERDAY BOX
# ('YESTERDAY', 'GIVE2')-<class 'KeyError'>-YESTERDAY GIVE2
# ('YESTERDAY', 'GIVE3')-<class 'KeyError'>-YESTERDAY GIVE3
# ('YESTERDAY', 'GET') -5.282729399999994--YESTERDAY GET
# ('YESTERDAY', 'PUTASIDE') -5.282729399999994--YESTERDAY PUTASIDE
# ('IX', 'JOHN') -2.784979809999996--IX JOHN
# ('IX', 'WRITE') -3.842849610000002--IX WRITE
# ('IX', 'HOMEWORK') -3.842849610000002--IX HOMEWORK
# ('IX', 'IX-1P') -3.6466016099999905--IX IX-1P
# ('IX', 'SEE') -3.6466016099999905--IX SEE
# ('IX', 'YESTERDAY') -3.374887610000002--IX YESTERDAY
# ('IX', 'IX') -2.7089668099999926--IX IX
# ('IX', 'LOVE') -3.4898326099999935--IX LOVE
# ('IX', 'MARY') -2.9552976100000024--IX MARY
# ('IX', 'CAN') -3.4898326099999935--IX CAN
# ('IX', 'GO') -3.374887610000002--IX GO
# ('IX', 'GO1')-<class 'KeyError'>-IX GO1
# ('IX', 'FUTURE') -3.374887610000002--IX FUTURE
# ('IX', 'GO2')-<class 'KeyError'>-IX GO2
# ('IX', 'PARTY') -3.842849610000002--IX PARTY
# ('IX', 'FUTURE1')-<class 'KeyError'>-IX FUTURE1
# ('IX', 'HIT') -3.170149809999998--IX HIT
# ('IX', 'BLAME') -3.6466016099999905--IX BLAME
# ('IX', 'FRED') -3.842849610000002--IX FRED
# ('IX', 'FISH') -3.842849610000002--IX FISH
# ('IX', 'WONT') -3.7523346099999912--IX WONT
# ('IX', 'EAT') -3.7523346099999912--IX EAT
# ('IX', 'BUT') -3.842849610000002--IX BUT
# ('IX', 'CHICKEN') -3.842849610000002--IX CHICKEN
# ('IX', 'VEGETABLE') -3.6466016099999905--IX VEGETABLE
# ('IX', 'CHINA') -3.842849610000002--IX CHINA
# ('IX', 'PEOPLE') -3.1203988099999975--IX PEOPLE
# ('IX', 'PREFER') -3.4898326099999935--IX PREFER
# ('IX', 'BROCCOLI') -3.842849610000002--IX BROCCOLI
# ('IX', 'LIKE') -3.2356238099999928--IX LIKE
# ('IX', 'LEAVE') -3.842849610000002--IX LEAVE
# ('IX', 'SAY') -3.7523346099999912--IX SAY
# ('IX', 'BUY') -3.2090256099999976--IX BUY
# ('IX', 'HOUSE') -3.7523346099999912--IX HOUSE
# ('IX', 'KNOW') -3.7523346099999912--IX KNOW
# ('IX', 'CORN') -3.7523346099999912--IX CORN
# ('IX', 'CORN1')-<class 'KeyError'>-IX CORN1
# ('IX', 'THINK') -3.170149809999998--IX THINK
# ('IX', 'NOT') -3.4898326099999935--IX NOT
# ('IX', 'PAST') -3.842849610000002--IX PAST
# ('IX', 'LIVE') -3.842849610000002--IX LIVE
# ('IX', 'CHICAGO') -3.842849610000002--IX CHICAGO
# ('IX', 'CAR') -2.977925810000002--IX CAR
# ('IX', 'SHOULD') -3.6466016099999905--IX SHOULD
# ('IX', 'DECIDE') -3.842849610000002--IX DECIDE
# ('IX', 'VISIT') -3.284086610000003--IX VISIT
# ('IX', 'MOVIE') -3.842849610000002--IX MOVIE
# ('IX', 'WANT') -3.842849610000002--IX WANT
# ('IX', 'SELL') -3.7523346099999912--IX SELL
# ('IX', 'TOMORROW') -3.842849610000002--IX TOMORROW
# ('IX', 'NEXT-WEEK') -3.842849610000002--IX NEXT-WEEK
# ('IX', 'NEW-YORK') -3.842849610000002--IX NEW-YORK
# ('IX', 'LAST-WEEK') -3.842849610000002--IX LAST-WEEK
# ('IX', 'WILL') -3.842849610000002--IX WILL
# ('IX', 'FINISH') -3.7523346099999912--IX FINISH
# ('IX', 'ANN') -3.842849610000002--IX ANN
# ('IX', 'READ') -3.7523346099999912--IX READ
# ('IX', 'BOOK') -2.9699258099999923--IX BOOK
# ('IX', 'CHOCOLATE') -3.842849610000002--IX CHOCOLATE
# ('IX', 'FIND') -3.842849610000002--IX FIND
# ('IX', 'SOMETHING-ONE') -3.0204268100000036--IX SOMETHING-ONE
# ('IX', 'POSS') -3.284086610000003--IX POSS
# ('IX', 'BROTHER') -3.7523346099999912--IX BROTHER
# ('IX', 'ARRIVE') -3.1450466099999943--IX ARRIVE
# ('IX', 'HERE') -3.842849610000002--IX HERE
# ('IX', 'GIVE') -2.9036748099999983--IX GIVE
# ('IX', 'MAN') -3.170149809999998--IX MAN
# ('IX', 'NEW') -3.149277810000001--IX NEW
# ('IX', 'COAT') -3.842849610000002--IX COAT
# ('IX', 'WOMAN') -3.1679038099999985--IX WOMAN
# ('IX', 'GIVE1')-<class 'KeyError'>-IX GIVE1
# ('IX', 'HAVE') -3.1203988099999975--IX HAVE
# ('IX', 'FRANK') -3.7523346099999912--IX FRANK
# ('IX', 'BREAK-DOWN') -3.842849610000002--IX BREAK-DOWN
# ('IX', 'SEARCH-FOR') -3.842849610000002--IX SEARCH-FOR
# ('IX', 'WHO') -2.8117528100000015--IX WHO
# ('IX', 'WHAT') -2.8845266099999947--IX WHAT
# ('IX', 'LEG') -3.842849610000002--IX LEG
# ('IX', 'FRIEND') -3.842849610000002--IX FRIEND
# ('IX', 'CANDY') -3.842849610000002--IX CANDY
# ('IX', 'BLUE') -3.842849610000002--IX BLUE
# ('IX', 'SUE') -3.842849610000002--IX SUE
# ('IX', 'BUY1')-<class 'KeyError'>-IX BUY1
# ('IX', 'STOLEN') -3.842849610000002--IX STOLEN
# ('IX', 'OLD') -3.842849610000002--IX OLD
# ('IX', 'STUDENT') -3.842849610000002--IX STUDENT
# ('IX', 'VIDEOTAPE') -3.7523346099999912--IX VIDEOTAPE
# ('IX', 'BORROW') -3.842849610000002--IX BORROW
# ('IX', 'MOTHER') -3.6466016099999905--IX MOTHER
# ('IX', 'POTATO') -3.842849610000002--IX POTATO
# ('IX', 'TELL') -3.7523346099999912--IX TELL
# ('IX', 'BILL') -3.7523346099999912--IX BILL
# ('IX', 'THROW') -3.842849610000002--IX THROW
# ('IX', 'APPLE') -3.7523346099999912--IX APPLE
# ('GIVE3', 'CORN1')-<class 'KeyError'>-GIVE3 CORN1
# ('GIVE3', 'THINK')-<class 'KeyError'>-GIVE3 THINK
# ('GIVE3', 'NOT')-<class 'KeyError'>-GIVE3 NOT
# ('GIVE3', 'PAST')-<class 'KeyError'>-GIVE3 PAST
# ('GIVE3', 'LIVE')-<class 'KeyError'>-GIVE3 LIVE
# ('GIVE3', 'CHICAGO')-<class 'KeyError'>-GIVE3 CHICAGO
# ('GIVE3', 'CAR')-<class 'KeyError'>-GIVE3 CAR
# ('GIVE3', 'SHOULD')-<class 'KeyError'>-GIVE3 SHOULD
# ('GIVE3', 'DECIDE')-<class 'KeyError'>-GIVE3 DECIDE
# ('GIVE3', 'VISIT')-<class 'KeyError'>-GIVE3 VISIT
# ('GIVE3', 'MOVIE')-<class 'KeyError'>-GIVE3 MOVIE
# ('GIVE3', 'WANT')-<class 'KeyError'>-GIVE3 WANT
# ('GIVE3', 'SELL')-<class 'KeyError'>-GIVE3 SELL
# ('GIVE3', 'TOMORROW')-<class 'KeyError'>-GIVE3 TOMORROW
# ('GIVE3', 'NEXT-WEEK')-<class 'KeyError'>-GIVE3 NEXT-WEEK
# ('GIVE3', 'NEW-YORK')-<class 'KeyError'>-GIVE3 NEW-YORK
# ('GIVE3', 'LAST-WEEK')-<class 'KeyError'>-GIVE3 LAST-WEEK
# ('GIVE3', 'WILL')-<class 'KeyError'>-GIVE3 WILL
# ('GIVE3', 'FINISH')-<class 'KeyError'>-GIVE3 FINISH
# ('GIVE3', 'ANN')-<class 'KeyError'>-GIVE3 ANN
# ('GIVE3', 'READ')-<class 'KeyError'>-GIVE3 READ
# ('GIVE3', 'BOOK')-<class 'KeyError'>-GIVE3 BOOK
# ('GIVE3', 'CHOCOLATE')-<class 'KeyError'>-GIVE3 CHOCOLATE
# ('GIVE3', 'FIND')-<class 'KeyError'>-GIVE3 FIND
# ('GIVE3', 'SOMETHING-ONE')-<class 'KeyError'>-GIVE3 SOMETHING-ONE
# ('GIVE3', 'POSS')-<class 'KeyError'>-GIVE3 POSS
# ('GIVE3', 'BROTHER')-<class 'KeyError'>-GIVE3 BROTHER
# ('GIVE3', 'ARRIVE')-<class 'KeyError'>-GIVE3 ARRIVE
# ('GIVE3', 'HERE')-<class 'KeyError'>-GIVE3 HERE
# ('GIVE3', 'GIVE')-<class 'KeyError'>-GIVE3 GIVE
# ('GIVE3', 'MAN')-<class 'KeyError'>-GIVE3 MAN
# ('GIVE3', 'NEW')-<class 'KeyError'>-GIVE3 NEW
# ('GIVE3', 'COAT')-<class 'KeyError'>-GIVE3 COAT
# ('GIVE3', 'WOMAN')-<class 'KeyError'>-GIVE3 WOMAN
# ('GIVE3', 'GIVE1')-<class 'KeyError'>-GIVE3 GIVE1
# ('GIVE3', 'HAVE')-<class 'KeyError'>-GIVE3 HAVE
# ('GIVE3', 'FRANK')-<class 'KeyError'>-GIVE3 FRANK
# ('GIVE3', 'BREAK-DOWN')-<class 'KeyError'>-GIVE3 BREAK-DOWN
# ('GIVE3', 'SEARCH-FOR')-<class 'KeyError'>-GIVE3 SEARCH-FOR
# ('GIVE3', 'WHO')-<class 'KeyError'>-GIVE3 WHO
# ('GIVE3', 'WHAT')-<class 'KeyError'>-GIVE3 WHAT
# ('GIVE3', 'LEG')-<class 'KeyError'>-GIVE3 LEG
# ('GIVE3', 'FRIEND')-<class 'KeyError'>-GIVE3 FRIEND
# ('GIVE3', 'CANDY')-<class 'KeyError'>-GIVE3 CANDY
# ('GIVE3', 'BLUE')-<class 'KeyError'>-GIVE3 BLUE
# ('GIVE3', 'SUE')-<class 'KeyError'>-GIVE3 SUE
# ('GIVE3', 'BUY1')-<class 'KeyError'>-GIVE3 BUY1
# ('GIVE3', 'STOLEN')-<class 'KeyError'>-GIVE3 STOLEN
# ('GIVE3', 'OLD')-<class 'KeyError'>-GIVE3 OLD
# ('GIVE3', 'STUDENT')-<class 'KeyError'>-GIVE3 STUDENT
# ('GIVE3', 'VIDEOTAPE')-<class 'KeyError'>-GIVE3 VIDEOTAPE
# ('GIVE3', 'BORROW')-<class 'KeyError'>-GIVE3 BORROW
# ('GIVE3', 'MOTHER')-<class 'KeyError'>-GIVE3 MOTHER
# ('GIVE3', 'POTATO')-<class 'KeyError'>-GIVE3 POTATO
# ('GIVE3', 'TELL')-<class 'KeyError'>-GIVE3 TELL
# ('GIVE3', 'BILL')-<class 'KeyError'>-GIVE3 BILL
# ('GIVE3', 'THROW')-<class 'KeyError'>-GIVE3 THROW
# ('GIVE3', 'APPLE')-<class 'KeyError'>-GIVE3 APPLE
# ('GIVE3', 'NAME')-<class 'KeyError'>-GIVE3 NAME
# ('GIVE3', 'SHOOT')-<class 'KeyError'>-GIVE3 SHOOT
# ('GIVE3', 'SAY-1P')-<class 'KeyError'>-GIVE3 SAY-1P
# ('GIVE3', 'SELF')-<class 'KeyError'>-GIVE3 SELF
# ('GIVE3', 'GROUP')-<class 'KeyError'>-GIVE3 GROUP
# ('GIVE3', 'JANA')-<class 'KeyError'>-GIVE3 JANA
# ('GIVE3', 'TOY1')-<class 'KeyError'>-GIVE3 TOY1
# ('GIVE3', 'MANY')-<class 'KeyError'>-GIVE3 MANY
# ('GIVE3', 'TOY')-<class 'KeyError'>-GIVE3 TOY
# ('GIVE3', 'ALL')-<class 'KeyError'>-GIVE3 ALL
# ('GIVE3', 'BOY')-<class 'KeyError'>-GIVE3 BOY
# ('GIVE3', 'TEACHER')-<class 'KeyError'>-GIVE3 TEACHER
# ('GIVE3', 'GIRL')-<class 'KeyError'>-GIVE3 GIRL
# ('GIVE3', 'BOX')-<class 'KeyError'>-GIVE3 BOX
# ('GIVE3', 'GIVE2')-<class 'KeyError'>-GIVE3 GIVE2
# ('GIVE3', 'GIVE3')-<class 'KeyError'>-GIVE3 GIVE3
# ('GIVE3', 'GET')-<class 'KeyError'>-GIVE3 GET
# ('GIVE3', 'PUTASIDE')-<class 'KeyError'>-GIVE3 PUTASIDE
# ('GET', 'JOHN') -4.863139399999994--GET JOHN
# ('GET', 'WRITE') -5.750691399999994--GET WRITE
# ('GET', 'GIRL') -5.660176399999997--GET GIRL
# ('GET', 'BOX') -5.660176399999997--GET BOX
# ('GET', 'GIVE2')-<class 'KeyError'>-GET GIVE2
# ('GET', 'GIVE3')-<class 'KeyError'>-GET GIVE3
# ('GET', 'GET') -5.750691399999994--GET GET
# ('GET', 'PUTASIDE') -5.750691399999994--GET PUTASIDE
# ('PUTASIDE', 'JOHN') -4.863139500000003--PUTASIDE JOHN
# ('PUTASIDE', 'WRITE') -5.750691500000002--PUTASIDE WRITE
# ('PUTASIDE', 'HOMEWORK') -5.750691500000002--PUTASIDE HOMEWORK
# ('PUTASIDE', 'IX-1P') -5.554443499999991--PUTASIDE IX-1P
# ('PUTASIDE', 'SEE') -5.554443499999991--PUTASIDE SEE
# ('PUTASIDE', 'YESTERDAY') -5.282729500000002--PUTASIDE YESTERDAY
# ('PUTASIDE', 'IX') -4.704034499999992--PUTASIDE IX
# ('PUTASIDE', 'LOVE') -5.397674499999994--PUTASIDE LOVE
# ('PUTASIDE', 'MARY') -4.863139500000003--PUTASIDE MARY
# ('PUTASIDE', 'CAN') -5.397674499999994--PUTASIDE CAN
# ('PUTASIDE', 'GO') -5.282729500000002--PUTASIDE GO
# ('PUTASIDE', 'GO1')-<class 'KeyError'>-PUTASIDE GO1
# ('PUTASIDE', 'FUTURE') -5.282729500000002--PUTASIDE FUTURE
# ('PUTASIDE', 'GO2')-<class 'KeyError'>-PUTASIDE GO2
# ('PUTASIDE', 'PARTY') -5.750691500000002--PUTASIDE PARTY
# ('PUTASIDE', 'FUTURE1')-<class 'KeyError'>-PUTASIDE FUTURE1
# ('PUTASIDE', 'HIT') -5.750691500000002--PUTASIDE HIT
# ('PUTASIDE', 'BLAME') -5.554443499999991--PUTASIDE BLAME
# ('PUTASIDE', 'FRED') -5.750691500000002--PUTASIDE FRED
# ('PUTASIDE', 'FISH') -5.750691500000002--PUTASIDE FISH
# ('PUTASIDE', 'WONT') -5.6601764999999915--PUTASIDE WONT
# ('PUTASIDE', 'EAT') -5.6601764999999915--PUTASIDE EAT
# ('PUTASIDE', 'BUT') -5.750691500000002--PUTASIDE BUT
# ('PUTASIDE', 'CHICKEN') -5.750691500000002--PUTASIDE CHICKEN
# ('PUTASIDE', 'VEGETABLE') -5.554443499999991--PUTASIDE VEGETABLE
# ('PUTASIDE', 'CHINA') -5.750691500000002--PUTASIDE CHINA
# ('PUTASIDE', 'PEOPLE') -5.554443499999991--PUTASIDE PEOPLE
# ('PUTASIDE', 'PREFER') -5.397674499999994--PUTASIDE PREFER
# ('PUTASIDE', 'BROCCOLI') -5.750691500000002--PUTASIDE BROCCOLI
# ('PUTASIDE', 'LIKE') -5.554443499999991--PUTASIDE LIKE
# ('PUTASIDE', 'LEAVE') -5.750691500000002--PUTASIDE LEAVE
# ('PUTASIDE', 'SAY') -5.6601764999999915--PUTASIDE SAY
# ('PUTASIDE', 'BUY') -5.116867499999998--PUTASIDE BUY
# ('PUTASIDE', 'HOUSE') -5.6601764999999915--PUTASIDE HOUSE
# ('PUTASIDE', 'KNOW') -5.6601764999999915--PUTASIDE KNOW
# ('PUTASIDE', 'CORN') -5.6601764999999915--PUTASIDE CORN
# ('PUTASIDE', 'CORN1')-<class 'KeyError'>-PUTASIDE CORN1
# ('PUTASIDE', 'THINK') -5.750691500000002--PUTASIDE THINK
# ('PUTASIDE', 'NOT') -5.397674499999994--PUTASIDE NOT
# ('PUTASIDE', 'PAST') -5.750691500000002--PUTASIDE PAST
# ('PUTASIDE', 'LIVE') -5.750691500000002--PUTASIDE LIVE
# ('PUTASIDE', 'CHICAGO') -5.750691500000002--PUTASIDE CHICAGO
# ('PUTASIDE', 'CAR') -5.191928500000003--PUTASIDE CAR
# ('PUTASIDE', 'SHOULD') -5.554443499999991--PUTASIDE SHOULD
# ('PUTASIDE', 'DECIDE') -5.750691500000002--PUTASIDE DECIDE
# ('PUTASIDE', 'VISIT') -5.191928500000003--PUTASIDE VISIT
# ('PUTASIDE', 'MOVIE') -5.750691500000002--PUTASIDE MOVIE
# ('PUTASIDE', 'WANT') -5.750691500000002--PUTASIDE WANT
# ('PUTASIDE', 'SELL') -5.6601764999999915--PUTASIDE SELL
# ('PUTASIDE', 'TOMORROW') -5.750691500000002--PUTASIDE TOMORROW
# ('PUTASIDE', 'NEXT-WEEK') -5.750691500000002--PUTASIDE NEXT-WEEK
# ('PUTASIDE', 'NEW-YORK') -5.750691500000002--PUTASIDE NEW-YORK
# ('PUTASIDE', 'LAST-WEEK') -5.750691500000002--PUTASIDE LAST-WEEK
# ('PUTASIDE', 'WILL') -5.750691500000002--PUTASIDE WILL
# ('PUTASIDE', 'FINISH') -5.6601764999999915--PUTASIDE FINISH
# ('PUTASIDE', 'ANN') -5.750691500000002--PUTASIDE ANN
# ('PUTASIDE', 'READ') -5.6601764999999915--PUTASIDE READ
# ('PUTASIDE', 'BOOK') -5.052888499999995--PUTASIDE BOOK
# ('PUTASIDE', 'CHOCOLATE') -5.750691500000002--PUTASIDE CHOCOLATE
# ('PUTASIDE', 'FIND') -5.750691500000002--PUTASIDE FIND
# ('PUTASIDE', 'SOMETHING-ONE') -5.282729500000002--PUTASIDE SOMETHING-ONE
# ('PUTASIDE', 'POSS') -5.191928500000003--PUTASIDE POSS
# ('PUTASIDE', 'BROTHER') -5.6601764999999915--PUTASIDE BROTHER
# ('PUTASIDE', 'ARRIVE') -5.052888499999995--PUTASIDE ARRIVE
# ('PUTASIDE', 'HERE') -5.750691500000002--PUTASIDE HERE
# ('PUTASIDE', 'GIVE') -5.052888499999995--PUTASIDE GIVE
# ('PUTASIDE', 'MAN') -5.750691500000002--PUTASIDE MAN
# ('PUTASIDE', 'NEW') -5.6601764999999915--PUTASIDE NEW
# ('PUTASIDE', 'COAT') -5.750691500000002--PUTASIDE COAT
# ('PUTASIDE', 'WOMAN') -5.397674499999994--PUTASIDE WOMAN
# ('PUTASIDE', 'GIVE1')-<class 'KeyError'>-PUTASIDE GIVE1
# ('PUTASIDE', 'HAVE') -5.554443499999991--PUTASIDE HAVE
# ('PUTASIDE', 'FRANK') -5.6601764999999915--PUTASIDE FRANK
# ('PUTASIDE', 'BREAK-DOWN') -5.750691500000002--PUTASIDE BREAK-DOWN
# ('PUTASIDE', 'SEARCH-FOR') -5.750691500000002--PUTASIDE SEARCH-FOR
# ('PUTASIDE', 'WHO') -4.9033795--PUTASIDE WHO
# ('PUTASIDE', 'WHAT') -4.792368499999995--PUTASIDE WHAT
# ('PUTASIDE', 'LEG') -5.750691500000002--PUTASIDE LEG
# ('PUTASIDE', 'FRIEND') -5.750691500000002--PUTASIDE FRIEND
# ('PUTASIDE', 'CANDY') -5.750691500000002--PUTASIDE CANDY
# ('PUTASIDE', 'BLUE') -5.750691500000002--PUTASIDE BLUE
# ('PUTASIDE', 'SUE') -5.750691500000002--PUTASIDE SUE
# ('PUTASIDE', 'BUY1')-<class 'KeyError'>-PUTASIDE BUY1
# ('PUTASIDE', 'STOLEN') -5.750691500000002--PUTASIDE STOLEN
# ('PUTASIDE', 'OLD') -5.750691500000002--PUTASIDE OLD
# ('PUTASIDE', 'STUDENT') -5.750691500000002--PUTASIDE STUDENT
# ('PUTASIDE', 'VIDEOTAPE') -5.6601764999999915--PUTASIDE VIDEOTAPE
# ('PUTASIDE', 'BORROW') -5.750691500000002--PUTASIDE BORROW
# ('PUTASIDE', 'MOTHER') -5.554443499999991--PUTASIDE MOTHER
# ('PUTASIDE', 'POTATO') -5.750691500000002--PUTASIDE POTATO
# ('PUTASIDE', 'TELL') -5.6601764999999915--PUTASIDE TELL
# ('PUTASIDE', 'BILL') -5.6601764999999915--PUTASIDE BILL
# ('PUTASIDE', 'THROW') -5.750691500000002--PUTASIDE THROW
# ('PUTASIDE', 'APPLE') -5.6601764999999915--PUTASIDE APPLE
# ('PUTASIDE', 'NAME') -5.750691500000002--PUTASIDE NAME
# ('PUTASIDE', 'SHOOT') -5.750691500000002--PUTASIDE SHOOT
# ('PUTASIDE', 'SAY-1P') -5.750691500000002--PUTASIDE SAY-1P
# ('PUTASIDE', 'SELF') -5.750691500000002--PUTASIDE SELF
# ('PUTASIDE', 'GROUP') -5.750691500000002--PUTASIDE GROUP
# ('PUTASIDE', 'JANA') -5.750691500000002--PUTASIDE JANA
# ('PUTASIDE', 'TOY1')-<class 'KeyError'>-PUTASIDE TOY1
# ('PUTASIDE', 'MANY') -5.750691500000002--PUTASIDE MANY
# ('PUTASIDE', 'TOY') -5.750691500000002--PUTASIDE TOY
# ('PUTASIDE', 'ALL') -5.750691500000002--PUTASIDE ALL
# ('PUTASIDE', 'BOY') -5.6601764999999915--PUTASIDE BOY
# ('PUTASIDE', 'TEACHER') -5.6601764999999915--PUTASIDE TEACHER
# ('PUTASIDE', 'GIRL') -5.6601764999999915--PUTASIDE GIRL
# ('PUTASIDE', 'BOX') -5.6601764999999915--PUTASIDE BOX
# ('PUTASIDE', 'GIVE2')-<class 'KeyError'>-PUTASIDE GIVE2
# ('PUTASIDE', 'GIVE3')-<class 'KeyError'>-PUTASIDE GIVE3
# ('PUTASIDE', 'GET') -5.750691500000002--PUTASIDE GET
# ('PUTASIDE', 'PUTASIDE') -5.750691500000002--PUTASIDE PUTASIDE
#
# **** WER = 0.9887640449438202
# Total correct: 2 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *IX HOMEWORK                                             JOHN WRITE HOMEWORK

# %%
import my_recognizer
reload(my_recognizer)
from my_recognizer import recognize_gram_2
guesses = recognize_gram_2(models, test_set,model_arpa,C=10)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.5
# Total correct: 89 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *IX HOMEWORK                                             JOHN WRITE HOMEWORK
#     7: JOHN *BUY GO *ARRIVE                                          JOHN CAN GO CAN
#    12: JOHN *BOX *FUTURE CAN                                         JOHN CAN GO CAN
#    21: JOHN FISH WONT *MARY *HOUSE *GO *FUTURE *MARY                 JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX
#    28: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX
#    30: JOHN *SHOULD *NOT IX IX                                       JOHN LIKE IX IX IX
#    36: *JOHN *JOHN *GIVE IX *GIRL *IX                                MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN IX *WHO *WHO *JOHN                                       JOHN IX THINK MARY LOVE
#    43: JOHN *IX BUY HOUSE                                            JOHN MUST BUY HOUSE
#    50: *JOHN *FUTURE BUY CAR *MARY                                   FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *IX *JOHN BUY HOUSE                                      JOHN SHOULD NOT BUY HOUSE
#    57: JOHN *MARY VISIT MARY                                         JOHN DECIDE VISIT MARY
#    67: JOHN *IX *GIRL BUY HOUSE                                      JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *IX *GO MARY                                             JOHN WILL VISIT MARY
#    74: JOHN *IX VISIT MARY                                           JOHN NOT VISIT MARY
#    77: *JOHN *ARRIVE MARY                                            ANN BLAME MARY
#    84: *JOHN *GO *IX BOOK                                            IX-1P FIND SOMETHING-ONE BOOK
#    89: JOHN IX GIVE *IX *GIVE *WHAT *CAN                             JOHN IX GIVE MAN IX NEW COAT
#    90: JOHN GIVE IX *GIVE WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *IX IX *IX *IX *JOHN                                     JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: *IX NEW CAR *HOUSE                                            POSS NEW CAR BREAK-DOWN
#   105: JOHN *IX                                                      JOHN LEG
#   107: JOHN POSS *VISIT *MARY *JOHN                                  JOHN POSS FRIEND HAVE CANDY
#   108: *IX *STUDENT                                                  WOMAN ARRIVE
#   113: *JOHN CAR *MARY *JOHN *LOVE                                   IX CAR BLUE SUE BUY
#   119: *JOHN *ARRIVE IX CAR *WHO                                     SUE BUY IX CAR BLUE
#   122: JOHN *CAR BOOK                                                JOHN READ BOOK
#   139: JOHN BUY *HOUSE *JOHN *LOVE                                   JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY *HOUSE WHAT BOOK                                     JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE JOHN *MARY                                               LOVE JOHN WHO
#   167: JOHN *SHOULD *IX LOVE MARY                                    JOHN IX SAY LOVE MARY
#   171: JOHN *SHOULD *ARRIVE                                          JOHN MARY BLAME
#   174: *CAR *JOHN GIVE1 *MARY *BLAME                                 PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN ARRIVE                                                   JOHN ARRIVE
#   184: *IX *IX *GIVE1 TEACHER *IX                                    ALL BOY GIVE TEACHER APPLE
#   189: JOHN *IX GIRL *BOOK                                           JOHN GIVE GIRL BOX
#   193: JOHN *IX GIRL BOX                                             JOHN GIVE GIRL BOX
#   199: *JOHN *ARRIVE WHO                                             LIKE CHOCOLATE WHO
#   201: JOHN *IX *WHO *JOHN BUY HOUSE                                 JOHN TELL MARY IX-1P BUY HOUSE

# %%
import my_recognizer
reload(my_recognizer)
import copy
from my_recognizer import recognize_gram_3
l_test=copy.copy(test_set)
item=list(test_set.sentences_index.items())
l_test.sentences_index={}
for n in range(1):
    k,v=item[n]
    l_test.sentences_index[k]=v
                                                
guesses = recognize_gram_3(models, l_test,model_arpa,C=7)
guesses = guesses  + [1] * (l_test.num_items - len(guesses))
show_errors(guesses, l_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-6cb935423c9d> in <module>()
#      10     l_test.sentences_index[k]=v
#      11
# ---> 12 guesses = recognize_gram_3(models, l_test,model_arpa,C=7)
#      13 guesses = guesses  + [1] * (l_test.num_items - len(guesses))
#      14 show_errors(guesses, l_test)
#
# /home/jota/Escritorio/udacity/aind/AIND-Recognizer/my_recognizer.py in recognize_gram_3(models, test_set, model_arpa, C)
#     255
#     256     probabilities,guesses=recognize(models,test_set)
# --> 257     probabilities_gram_init=get_gram_3_probabilities_total(models)
#     258     guesses=[]
#     259     for sentences_id in test_set.sentences_index:
#
# /home/jota/Escritorio/udacity/aind/AIND-Recognizer/my_recognizer.py in get_gram_3_probabilities_total(models)
#     201         for (w1,w2,w3) in list_combine:
#     202           try:
# --> 203             dict_retorno[(w1,w2,w3)]=model_arpa.log_s(w1 + " " +w2 + " " + w3, eos=False)
#     204             #print(str((w1,w2)) + " " + str(dict_retorno[(w1,w2)]) + "--" + w1 + " " +w2 )
#     205           except Exception as e:
#
# /home/jota/anaconda3/lib/python3.6/site-packages/arpa/models/base.py in log_s(self, sentence, sos, eos)
#      47         words = self._check_input(sentence)
#      48         if self._unk:
# ---> 49             words = self._replace_unks(words)
#      50         if sos:
#      51             words = (sos, ) + words
#
# /home/jota/anaconda3/lib/python3.6/site-packages/arpa/models/base.py in _replace_unks(self, words)
#     121
#     122     def _replace_unks(self, words):
# --> 123         return tuple((w if w in self else self._unk) for w in words)
#
# /home/jota/anaconda3/lib/python3.6/site-packages/arpa/models/base.py in <genexpr>(.0)
#     121
#     122     def _replace_unks(self, words):
# --> 123         return tuple((w if w in self else self._unk) for w in words)
#
# /home/jota/anaconda3/lib/python3.6/site-packages/arpa/models/base.py in __contains__(self, word)
#      12
#      13     def __contains__(self, word):
# ---> 14         return word in self.vocabulary()
#      15
#      16     def __len__(self):
#
# /home/jota/anaconda3/lib/python3.6/site-packages/arpa/models/simple.py in vocabulary(self)
#      31
#      32     def vocabulary(self):
# ---> 33         return sorted(set(word for ngram in self._ps.keys() for word in ngram))
#      34
#      35     def _entries(self, order):
#
# KeyboardInterrupt:

# %%
import my_recognizer
reload(my_recognizer)
from my_recognizer import recognize_gram_3
guesses = recognize_gram_3(models, test_set,model_arpa,C=10)
show_errors(guesses, test_set)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-b714ee8487bb> in <module>()
#       2 reload(my_recognizer)
#       3 from my_recognizer import recognize_gram_3
# ----> 4 guesses = recognize_gram_3(models, test_set,model_arpa,C=10)
#       5 show_errors(guesses, test_set)
#
# /home/jota/Escritorio/udacity/aind/AIND-Recognizer/my_recognizer.py in recognize_gram_3(models, test_set, model_arpa, C)
#     253       word_id1=test_set.sentences_index[sentences_id][0]
#     254       word_id2=test_set.sentences_index[sentences_id][1]
# --> 255       word_id3=test_set.sentences_index[sentences_id][2]
#     256       (first_gueses1,first_gueses2,first_gueses3)=Guess_3_total(probabilities[word_id1],probabilities[word_id2],probabilities[word_id3],probabilities_gram_init)
#     257       guesses.append(first_gueses1)
#
# IndexError: list index out of range

# %%
import my_recognizer
reload(my_recognizer)
import copy
from my_recognizer import recognize_gram_3_only_best
l_test=copy.copy(test_set)
item=list(test_set.sentences_index.items())
l_test.sentences_index={}
for n in range(5):
    k,v=item[n]
    l_test.sentences_index[k]=v
                                                
guesses = recognize_gram_3_only_best(models, l_test,model_arpa,C=15,n_best=20)
guesses = guesses  + [1] * (l_test.num_items - len(guesses))
show_errors(guesses, l_test)
# Out:
# DoSentence init
# DoSentence init ['JOHN', 'WRITE', 'HOMEWORK']
# DoSentence init
# DoSentence init ['JOHN', 'CAN', 'GO']
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N JOHN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WRITE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HOMEWORK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N IX-1P
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SEE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N YESTERDAY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N IX
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LOVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MARY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FUTURE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO2
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PARTY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FUTURE1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HIT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BLAME
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRED
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FISH
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WONT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N EAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHICKEN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VEGETABLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHINA
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PEOPLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PREFER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BROCCOLI
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LIKE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LEAVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SAY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HOUSE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N KNOW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CORN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CORN1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N THINK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NOT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PAST
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHICAGO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CAR
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SHOULD
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N DECIDE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VISIT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MOVIE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WANT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SELL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOMORROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEXT-WEEK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEW-YORK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LAST-WEEK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WILL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FINISH
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ANN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N READ
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOOK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHOCOLATE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FIND
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SOMETHING-ONE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N POSS
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BROTHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ARRIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HERE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N COAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WOMAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HAVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRANK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BREAK-DOWN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SEARCH-FOR
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WHO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WHAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LEG
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRIEND
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CANDY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BLUE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SUE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUY1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N STOLEN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N OLD
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N STUDENT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VIDEOTAPE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BORROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MOTHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N POTATO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TELL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BILL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N THROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N APPLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NAME
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SHOOT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SAY-1P
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SELF
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GROUP
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N JANA
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOY1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MANY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ALL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TEACHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIRL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOX
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE2
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE3
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GET
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PUTASIDE
# Guess JOHN -80.0787244616 -6.0114962000000105
# Guess WRITE -161.552572494 -6.89904820000001
# Guess HOMEWORK -114.293985321 -6.89904820000001
# Guess IX-1P -257.102869539 -6.702800199999999
# Guess SEE -185.82390842 -6.702800199999999
# Guess YESTERDAY -181.815407368 -6.43108620000001
# Guess IX -44.6498930656 -5.581054100000003
# Guess LOVE -103.949435323 -6.546031200000002
# Guess MARY -39.2113611204 -6.0114962000000105
# Guess CAN -26.2800219544 -4.470742600000008
# Guess GO -26.8779509928 -6.43108620000001
# Guess GO1 -207.831444767 -6.89904820000001
# Guess FUTURE -68.124311806 -5.798680099999999
# Guess GO2 -325.736748688 -6.89904820000001
# Guess PARTY -151.431680871 -5.8711871
# Guess FUTURE1 -325.812362388 -6.89904820000001
# Guess HIT -206.28615915 -6.89904820000001
# Guess BLAME -26.067660883 -6.702800199999999
# Guess FRED -302.984139238 -6.89904820000001
# Guess FISH -322.681483324 -6.89904820000001
# Guess WONT -224.028791533 -6.808533199999999
# Guess EAT -325.711058564 -6.808533199999999
# Guess BUT -263.786738006 -6.89904820000001
# Guess CHICKEN -265.501129652 -6.89904820000001
# Guess VEGETABLE -453.820320468 -6.702800199999999
# Guess CHINA -228.016408161 -6.89904820000001
# Guess PEOPLE -46.5854148941 -6.702800199999999
# Guess PREFER -111.976313661 -6.546031200000002
# Guess BROCCOLI -334.49391981 -6.89904820000001
# Guess LIKE -268.975174337 -6.702800199999999
# Guess LEAVE -499.971864604 -6.89904820000001
# Guess SAY -186.580915079 -6.808533199999999
# Guess BUY -50.0626141094 -6.265224200000006
# Guess HOUSE -7.57913409001 -6.808533199999999
# Guess KNOW -225.845586769 -6.808533199999999
# Guess CORN -494.771018148 -6.808533199999999
# Guess CORN1 -736.750048943 -6.89904820000001
# Guess THINK -801.577667173 -6.89904820000001
# Guess NOT -199.600397523 -6.546031200000002
# Guess PAST -398.176052134 -6.89904820000001
# Guess LIVE -212.000293391 -6.89904820000001
# Guess CHICAGO -201.178115552 -6.89904820000001
# Guess CAR -27.1544194633 -6.340285200000011
# Guess SHOULD -362.349511953 -5.994466100000011
# Guess DECIDE -29.5462414201 -6.89904820000001
# Guess VISIT -12.1680090892 -6.340285200000011
# Guess MOVIE -235.867317139 -5.8711871
# Guess WANT -118.889684285 -6.89904820000001
# Guess SELL -158.321938776 -6.808533199999999
# Guess TOMORROW -253.160318386 -6.89904820000001
# Guess NEXT-WEEK -150.04806741 -6.89904820000001
# Guess NEW-YORK -316.738432726 -5.8711871
# Guess LAST-WEEK -219.513588592 -6.89904820000001
# Guess WILL -325.003570493 -6.89904820000001
# Guess FINISH -221.077265068 -6.808533199999999
# Guess ANN -312.026025308 -6.89904820000001
# Guess READ -257.505654895 -6.808533199999999
# Guess BOOK -37.0146856208 -6.2012452000000025
# Guess CHOCOLATE -123.516930498 -6.89904820000001
# Guess FIND -265.016131563 -6.89904820000001
# Guess SOMETHING-ONE -276.286291866 -6.43108620000001
# Guess POSS -137.462089724 -6.340285200000011
# Guess BROTHER -123.523548631 -6.808533199999999
# Guess ARRIVE -5.53385396095 -6.2012452000000025
# Guess HERE -213.164839265 -6.89904820000001
# Guess GIVE -212.59446119 -6.2012452000000025
# Guess MAN -312.331834388 -6.89904820000001
# Guess NEW -40.9944163126 -6.808533199999999
# Guess COAT -169.699315178 -6.89904820000001
# Guess WOMAN -123.27144736 -6.546031200000002
# Guess GIVE1 -45.3995253775 -6.89904820000001
# Guess HAVE -74.7538875913 -6.702800199999999
# Guess FRANK -440.064414954 -6.808533199999999
# Guess BREAK-DOWN -45.9938303861 -6.89904820000001
# Guess SEARCH-FOR -427.569125192 -6.89904820000001
# Guess WHO -184.090970557 -6.051736200000008
# Guess WHAT -33.6471272713 -5.940725200000003
# Guess LEG -299.752137472 -6.89904820000001
# Guess FRIEND -186.325421002 -6.89904820000001
# Guess CANDY -372.62617055 -6.89904820000001
# Guess BLUE -407.706602698 -6.89904820000001
# Guess SUE -395.017368706 -6.89904820000001
# Guess BUY1 -161.839427903 -6.89904820000001
# Guess STOLEN -172.01545861 -6.89904820000001
# Guess OLD -215.306063014 -6.89904820000001
# Guess STUDENT -19.0619371092 -6.89904820000001
# Guess VIDEOTAPE -105.416703076 -6.808533199999999
# Guess BORROW -232.152723313 -6.89904820000001
# Guess MOTHER -241.433591737 -6.702800199999999
# Guess POTATO -209.663700301 -6.89904820000001
# Guess TELL -419.774030191 -6.808533199999999
# Guess BILL -853.272949147 -6.808533199999999
# Guess THROW -308.176820081 -6.89904820000001
# Guess APPLE -313.02312428 -6.808533199999999
# Guess NAME -376.673248177 -6.89904820000001
# Guess SHOOT -369.351892204 -6.89904820000001
# Guess SAY-1P -379.030517252 -6.89904820000001
# Guess SELF -703.333990868 -6.89904820000001
# Guess GROUP -147.021398131 -6.89904820000001
# Guess JANA -297.494914101 -6.89904820000001
# Guess TOY1 -453.534031551 -6.89904820000001
# Guess MANY -33.15415044 -6.89904820000001
# Guess TOY -7.12151207336 -6.89904820000001
# Guess ALL -305.542594617 -6.89904820000001
# Guess BOY -159.218430605 -6.808533199999999
# Guess TEACHER -39.1194165183 -6.808533199999999
# Guess GIRL -311.118143435 -6.808533199999999
# Guess BOX -96.2250919591 -6.808533199999999
# Guess GIVE2 -360.380722232 -6.89904820000001
# Guess GIVE3 -136.703553444 -6.89904820000001
# Guess GET -163.775943567 -6.89904820000001
# Guess PUTASIDE -402.961906659 -6.89904820000001
# DoSentence init
# DoSentence init ['JOHN', 'CAN', 'GO']
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N JOHN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WRITE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HOMEWORK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N IX-1P
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SEE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N YESTERDAY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N IX
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LOVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MARY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FUTURE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GO2
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PARTY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FUTURE1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HIT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BLAME
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRED
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FISH
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WONT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N EAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHICKEN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VEGETABLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHINA
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PEOPLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PREFER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BROCCOLI
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LIKE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LEAVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SAY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HOUSE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N KNOW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CORN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CORN1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N THINK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NOT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PAST
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHICAGO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CAR
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SHOULD
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N DECIDE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VISIT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MOVIE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WANT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SELL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOMORROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEXT-WEEK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEW-YORK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LAST-WEEK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WILL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FINISH
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ANN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N READ
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOOK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CHOCOLATE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FIND
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SOMETHING-ONE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N POSS
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BROTHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ARRIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HERE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NEW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N COAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WOMAN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N HAVE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRANK
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BREAK-DOWN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SEARCH-FOR
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WHO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N WHAT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N LEG
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N FRIEND
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N CANDY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BLUE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SUE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BUY1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N STOLEN
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N OLD
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N STUDENT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N VIDEOTAPE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BORROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MOTHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N POTATO
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TELL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BILL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N THROW
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N APPLE
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N NAME
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SHOOT
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SAY-1P
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N SELF
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GROUP
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N JANA
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOY1
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N MANY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TOY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N ALL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOY
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N TEACHER
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIRL
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N BOX
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE2
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GIVE3
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N GET
# get_gram_probabilities <['JOHN', 'CAN', 'GO']> <['CAN', 'GO']> C A N PUTASIDE
# Guess JOHN -2.78305486383 -6.0114962000000105
# Guess WRITE -32.4126982151 -6.89904820000001
# Guess HOMEWORK -39.9137379981 -6.89904820000001
# Guess IX-1P -111.812449481 -6.702800199999999
# Guess SEE -74.0339278897 -6.702800199999999
# Guess YESTERDAY -33.563107047 -6.43108620000001
# Guess IX -7.2104969408 -5.581054100000003
# Guess LOVE -12.3277253928 -6.546031200000002
# Guess MARY 6.63346115591 -6.0114962000000105
# Guess CAN 64.4092406881 -4.470742600000008
# Guess GO -4.75020577666 -6.43108620000001
# Guess GO1 -61.1718085038 -6.89904820000001
# Guess FUTURE -5.74811500186 -5.798680099999999
# Guess GO2 -330.368443111 -6.89904820000001
# Guess PARTY -51.4050167459 -5.8711871
# Guess FUTURE1 -94.8124704497 -6.89904820000001
# Guess HIT -179.582255052 -6.89904820000001
# Guess BLAME 21.305607453 -6.702800199999999
# Guess FRED -292.478495163 -6.89904820000001
# Guess FISH -110.614421453 -6.89904820000001
# Guess WONT -53.2412754708 -6.808533199999999
# Guess EAT -141.950545668 -6.808533199999999
# Guess BUT -116.459416439 -6.89904820000001
# Guess CHICKEN -53.0084158116 -6.89904820000001
# Guess VEGETABLE -209.110337613 -6.702800199999999
# Guess CHINA -169.01197564 -6.89904820000001
# Guess PEOPLE 9.78516618665 -6.702800199999999
# Guess PREFER -81.4628853342 -6.546031200000002
# Guess BROCCOLI -130.398003034 -6.89904820000001
# Guess LIKE -155.929154861 -6.702800199999999
# Guess LEAVE -308.103641723 -6.89904820000001
# Guess SAY -55.4142586514 -6.808533199999999
# Guess BUY -0.495456421594 -6.265224200000006
# Guess HOUSE 40.2627432473 -6.808533199999999
# Guess KNOW -115.550243726 -6.808533199999999
# Guess CORN -238.070362634 -6.808533199999999
# Guess CORN1 -376.608118583 -6.89904820000001
# Guess THINK -705.187442541 -6.89904820000001
# Guess NOT -89.8288292408 -6.546031200000002
# Guess PAST -169.469354307 -6.89904820000001
# Guess LIVE -209.662649261 -6.89904820000001
# Guess CHICAGO -137.579774976 -6.89904820000001
# Guess CAR 26.6193690922 -6.340285200000011
# Guess SHOULD -171.294573555 -5.994466100000011
# Guess DECIDE -17.5106106831 -6.89904820000001
# Guess VISIT 27.9517951814 -6.340285200000011
# Guess MOVIE -93.5495982212 -5.8711871
# Guess WANT -16.2201680728 -6.89904820000001
# Guess SELL -47.136944555 -6.808533199999999
# Guess TOMORROW -125.957357734 -6.89904820000001
# Guess NEXT-WEEK -168.98337614 -6.89904820000001
# Guess NEW-YORK -146.946972689 -5.8711871
# Guess LAST-WEEK -172.048316005 -6.89904820000001
# Guess WILL -214.012685305 -6.89904820000001
# Guess FINISH -71.7242534526 -6.808533199999999
# Guess ANN -159.375952355 -6.89904820000001
# Guess READ -168.744360384 -6.808533199999999
# Guess BOOK 31.0447713021 -6.2012452000000025
# Guess CHOCOLATE -98.3295014649 -6.89904820000001
# Guess FIND -201.114163742 -6.89904820000001
# Guess SOMETHING-ONE -65.1015342197 -6.43108620000001
# Guess POSS -72.5468716345 -6.340285200000011
# Guess BROTHER -99.4608004708 -6.808533199999999
# Guess ARRIVE 31.7930094659 -6.2012452000000025
# Guess HERE -37.4730361451 -6.89904820000001
# Guess GIVE -63.3162360429 -6.2012452000000025
# Guess MAN -169.283599765 -6.89904820000001
# Guess NEW -22.4143461797 -6.808533199999999
# Guess COAT 2.8040816533 -6.89904820000001
# Guess WOMAN -61.4015505035 -6.546031200000002
# Guess GIVE1 6.21340905216 -6.89904820000001
# Guess HAVE 7.52350464914 -6.702800199999999
# Guess FRANK -231.602571296 -6.808533199999999
# Guess BREAK-DOWN 6.14587561432 -6.89904820000001
# Guess SEARCH-FOR -227.522768282 -6.89904820000001
# Guess WHO -69.641364731 -6.051736200000008
# Guess WHAT 24.0089919741 -5.940725200000003
# Guess LEG -124.636402986 -6.89904820000001
# Guess FRIEND -56.3676353944 -6.89904820000001
# Guess CANDY -128.995869617 -6.89904820000001
# Guess BLUE -133.80775188 -6.89904820000001
# Guess SUE -244.864624035 -6.89904820000001
# Guess BUY1 -23.5969462546 -6.89904820000001
# Guess STOLEN -69.5140514494 -6.89904820000001
# Guess OLD -71.6606773156 -6.89904820000001
# Guess STUDENT -31.1081796398 -6.89904820000001
# Guess VIDEOTAPE -12.2615751937 -6.808533199999999
# Guess BORROW -192.662100308 -6.89904820000001
# Guess MOTHER -63.9444614431 -6.702800199999999
# Guess POTATO -60.2329777845 -6.89904820000001
# Guess TELL -336.510775036 -6.808533199999999
# Guess BILL -406.122584626 -6.808533199999999
# Guess THROW -212.297370589 -6.89904820000001
# Guess APPLE -124.308801047 -6.808533199999999
# Guess NAME -233.82524138 -6.89904820000001
# Guess SHOOT -281.497345873 -6.89904820000001
# Guess SAY-1P -192.085696766 -6.89904820000001
# Guess SELF -440.045900704 -6.89904820000001
# Guess GROUP -103.456092065 -6.89904820000001
# Guess JANA -143.561973939 -6.89904820000001
# Guess TOY1 -186.274336991 -6.89904820000001
# Guess MANY -20.6709814736 -6.89904820000001
# Guess TOY -122.619955447 -6.89904820000001
# Guess ALL -194.306255637 -6.89904820000001
# Guess BOY -92.2167303314 -6.808533199999999
# Guess TEACHER 11.9848022195 -6.808533199999999
# Guess GIRL -163.985817013 -6.808533199999999
# Guess BOX 29.937693918 -6.808533199999999
# Guess GIVE2 -201.8115282 -6.89904820000001
# Guess GIVE3 -63.3503283531 -6.89904820000001
# Guess GET -115.144292741 -6.89904820000001
# Guess PUTASIDE -288.810454301 -6.89904820000001
# DoSentence init
# DoSentence init ['JOHN', 'FISH', 'WONT']
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H JOHN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WRITE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H HOMEWORK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H IX-1P
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SEE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H YESTERDAY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H IX
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LOVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H MARY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GO1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FUTURE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GO2
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H PARTY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FUTURE1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H HIT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BLAME
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FRED
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FISH
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WONT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H EAT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BUT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CHICKEN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H VEGETABLE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CHINA
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H PEOPLE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H PREFER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BROCCOLI
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LIKE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LEAVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SAY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BUY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H HOUSE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H KNOW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CORN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CORN1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H THINK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H NOT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H PAST
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CHICAGO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CAR
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SHOULD
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H DECIDE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H VISIT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H MOVIE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WANT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SELL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H TOMORROW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H NEXT-WEEK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H NEW-YORK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LAST-WEEK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WILL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FINISH
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H ANN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H READ
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BOOK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CHOCOLATE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FIND
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SOMETHING-ONE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H POSS
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BROTHER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H ARRIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H HERE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H MAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H NEW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H COAT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WOMAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GIVE1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H HAVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FRANK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BREAK-DOWN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SEARCH-FOR
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WHO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H WHAT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H LEG
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H FRIEND
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H CANDY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BLUE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SUE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BUY1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H STOLEN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H OLD
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H STUDENT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H VIDEOTAPE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BORROW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H MOTHER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H POTATO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H TELL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BILL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H THROW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H APPLE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H NAME
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SHOOT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SAY-1P
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H SELF
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GROUP
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H JANA
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H TOY1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H MANY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H TOY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H ALL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BOY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H TEACHER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GIRL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H BOX
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GIVE2
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GIVE3
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H GET
# get_gram_probabilities <['JOHN', 'FISH', 'WONT']> <['FISH', 'WONT']> F I S H PUTASIDE
# Guess JOHN 68.2508528302 -5.316576799999993
# Guess WRITE 3.7963837305 -6.204128799999992
# Guess HOMEWORK -4.87466782605 -6.204128799999992
# Guess IX-1P 42.4330019792 -6.007880799999995
# Guess SEE 54.9944255947 -6.007880799999995
# Guess YESTERDAY 63.2996656922 -5.736166799999992
# Guess IX 65.1847847204 -5.157471799999996
# Guess LOVE 61.6510354175 -5.851111799999998
# Guess MARY 69.2126811746 -5.316576799999993
# Guess CAN 38.5884142134 -5.851111799999998
# Guess GO 46.8034439449 -5.736166799999992
# Guess GO1 13.2364896699 -6.204128799999992
# Guess FUTURE 60.5362620986 -5.736166799999992
# Guess GO2 -200.772592597 -6.204128799999992
# Guess PARTY -17.6818555472 -6.204128799999992
# Guess FUTURE1 48.9778138379 -6.204128799999992
# Guess HIT -33.4035793054 -6.204128799999992
# Guess BLAME 44.1152450158 -6.007880799999995
# Guess FRED -103.145609815 -6.204128799999992
# Guess FISH 43.724393073 -6.204128799999992
# Guess WONT 56.9136844592 -6.113613799999996
# Guess EAT 50.1460566736 -4.839989799999998
# Guess BUT -38.1578717213 -6.204128799999992
# Guess CHICKEN 37.0138045506 -6.204128799999992
# Guess VEGETABLE 41.5857750784 -6.007880799999995
# Guess CHINA 66.4405167726 -6.204128799999992
# Guess PEOPLE 19.1790065281 -6.007880799999995
# Guess PREFER 65.0767105724 -5.851111799999998
# Guess BROCCOLI 62.6279953842 -6.204128799999992
# Guess LIKE 51.1313514623 -6.007880799999995
# Guess LEAVE 33.3254454533 -6.204128799999992
# Guess SAY 53.6899306817 -6.113613799999996
# Guess BUY 27.4403409743 -5.570304800000002
# Guess HOUSE 61.318478742 -6.113613799999996
# Guess NAME 27.0169320281 -6.204128799999992
# Guess SHOOT 0.992945835703 -6.204128799999992
# Guess SAY-1P 63.011780922 -6.204128799999992
# Guess SELF 16.0581934919 -6.204128799999992
# Guess GROUP -34.7601226596 -6.204128799999992
# Guess JANA 24.1076896659 -6.204128799999992
# Guess TOY1 54.6299102929 -6.204128799999992
# Guess MANY 38.3926495457 -6.204128799999992
# Guess TOY -47.3653772794 -6.204128799999992
# Guess ALL 21.9044994649 -6.204128799999992
# Guess BOY 49.402845411 -6.113613799999996
# Guess TEACHER 41.3790990135 -6.113613799999996
# Guess GIRL 61.7237893125 -6.113613799999996
# Guess BOX 36.61284748 -6.113613799999996
# Guess GIVE2 -5.12360946144 -6.204128799999992
# Guess GIVE3 41.6919025779 -6.204128799999992
# Guess GET -44.8116285022 -6.204128799999992
# Guess PUTASIDE 56.9151720381 -6.204128799999992
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T JOHN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T WRITE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T HOMEWORK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T IX-1P
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T SEE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T YESTERDAY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T IX
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T LOVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T MARY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T GO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T GO1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FUTURE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T GO2
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T PARTY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FUTURE1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T HIT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BLAME
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FRED
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FISH
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T WONT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T EAT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BUT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CHICKEN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T VEGETABLE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CHINA
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T PEOPLE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T PREFER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BROCCOLI
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T LIKE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T LEAVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T SAY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BUY
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T HOUSE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T KNOW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CORN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CORN1
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T THINK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T NOT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T PAST
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T LIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CHICAGO
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CAR
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T SHOULD
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T DECIDE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T VISIT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T MOVIE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T WANT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T SELL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T TOMORROW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T NEXT-WEEK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T NEW-YORK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T LAST-WEEK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T WILL
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FINISH
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T ANN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T READ
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BOOK
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T CHOCOLATE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T FIND
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T SOMETHING-ONE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T POSS
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T BROTHER
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T ARRIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T HERE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T GIVE
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T MAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T NEW
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T COAT
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T WOMAN
# get_gram_probabilities <['JOHN', 'FISH', 'WONT', 'MARY']> <['WONT', 'MARY']> W O N T GIVE1
# ...
# Guess WHAT 26.3468912765 -4.497877509999995
# Guess LEG -12.476846132 -5.456200509999988
# Guess FRIEND -55.1001220405 -5.456200509999988
# Guess CANDY 29.2192721634 -5.456200509999988
# Guess BLUE -4.50631465346 -5.456200509999988
# Guess SUE 23.4121404929 -5.456200509999988
# Guess BUY1 -44.8825053383 -5.456200509999988
# Guess STOLEN -14.3785011661 -5.456200509999988
# Guess OLD -4.87904749609 -5.456200509999988
# Guess STUDENT 8.04533212034 -5.456200509999988
# Guess VIDEOTAPE 11.7745875347 -5.365685509999992
# Guess BORROW -37.9024627896 -5.456200509999988
# Guess MOTHER -31.692978981 -5.259952509999991
# Guess POTATO -10.2911562774 -5.456200509999988
# Guess TELL 38.0385090915 -5.365685509999992
# Guess BILL 33.454920614 -5.365685509999992
# Guess THROW 43.8666147059 -5.456200509999988
# Guess APPLE 32.2289506626 -5.365685509999992
# Guess NAME -33.8352310858 -5.456200509999988
# Guess SHOOT -0.0743512956599 -5.456200509999988
# Guess SAY-1P -7.5189124841 -4.783500709999998
# Guess SELF -47.8744482156 -5.456200509999988
# Guess GROUP -17.5215762477 -5.456200509999988
# Guess JANA 5.67922716993 -5.456200509999988
# Guess TOY1 30.234931892 -5.456200509999988
# Guess MANY 17.6007993093 -5.456200509999988
# Guess TOY -39.126191958 -5.456200509999988
# Guess ALL 10.0480582331 -5.456200509999988
# Guess BOY -4.06865442322 -5.365685509999992
# Guess TEACHER 16.7718964306 -5.365685509999992
# Guess GIRL 32.476801478 -4.762628709999987
# Guess BOX -25.9042609424 -5.365685509999992
# Guess GIVE2 -49.0488160367 -5.456200509999988
# Guess GIVE3 0.32929742422 -5.456200509999988
# Guess GET -14.9535523048 -5.456200509999988
# Guess PUTASIDE 38.4698193713 -5.456200509999988
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X JOHN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WRITE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X HOMEWORK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X IX-1P
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SEE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X YESTERDAY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X IX
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LOVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X MARY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CAN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GO
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GO1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FUTURE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GO2
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X PARTY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FUTURE1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X HIT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BLAME
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FRED
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FISH
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WONT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X EAT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BUT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CHICKEN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X VEGETABLE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CHINA
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X PEOPLE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X PREFER
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BROCCOLI
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LIKE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LEAVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SAY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BUY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X HOUSE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X KNOW
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CORN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CORN1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X THINK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X NOT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X PAST
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LIVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CHICAGO
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CAR
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SHOULD
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X DECIDE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X VISIT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X MOVIE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WANT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SELL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X TOMORROW
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X NEXT-WEEK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X NEW-YORK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LAST-WEEK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WILL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FINISH
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X ANN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X READ
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BOOK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CHOCOLATE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FIND
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SOMETHING-ONE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X POSS
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BROTHER
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X ARRIVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X HERE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GIVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X MAN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X NEW
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X COAT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WOMAN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GIVE1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X HAVE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FRANK
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BREAK-DOWN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SEARCH-FOR
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WHO
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X WHAT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X LEG
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X FRIEND
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X CANDY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BLUE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SUE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BUY1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X STOLEN
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X OLD
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X STUDENT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X VIDEOTAPE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BORROW
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X MOTHER
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X POTATO
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X TELL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BILL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X THROW
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X APPLE
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X NAME
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SHOOT
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SAY-1P
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X SELF
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GROUP
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X JANA
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X TOY1
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X MANY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X TOY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X ALL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BOY
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X TEACHER
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GIRL
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X BOX
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GIVE2
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GIVE3
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X GET
# get_gram_probabilities <['JOHN', 'IX', 'IX', 'IX']> <['IX', 'IX']> I X PUTASIDE
# Guess JOHN 56.9495284904 -4.398330709999996
# Guess WRITE -1.6531503708 -5.456200509999988
# Guess HOMEWORK -17.8438876801 -5.456200509999988
# Guess IX-1P 39.536970337 -5.259952509999991
# Guess SEE 11.5012041878 -5.259952509999991
# Guess YESTERDAY 42.6827645582 -4.988238509999988
# Guess IX 82.3184106714 -3.4623159099999867
# Guess LOVE 59.9255060916 -5.103183509999994
# Guess MARY 71.9675231946 -4.5686485099999885
# Guess CAN 31.408967823 -5.103183509999994
# Guess GO 61.8928880708 -4.988238509999988
# Guess GO1 12.8474803738 -5.456200509999988
# Guess FUTURE 43.5928691798 -4.988238509999988
# Guess GO2 -243.039831059 -5.456200509999988
# Guess PARTY -19.3362035398 -5.456200509999988
# Guess FUTURE1 23.8566946819 -5.456200509999988
# Guess HIT -55.2940780104 -4.783500709999998
# Guess BLAME 9.73089942341 -5.259952509999991
# Guess FRED -143.447251754 -5.456200509999988
# Guess FISH -47.2625662905 -5.456200509999988
# Guess WONT 34.1251092784 -5.365685509999992
# Guess EAT -11.5939493998 -5.365685509999992
# Guess BUT -55.2135291716 -5.456200509999988
# Guess CHICKEN -40.4375324206 -5.456200509999988
# Guess VEGETABLE -10.0190503082 -5.259952509999991
# Guess CHINA -28.3659913211 -5.456200509999988
# Guess PEOPLE 12.2459819443 -4.733749709999998
# Guess PREFER 16.6518451365 -5.103183509999994
# Guess BROCCOLI -0.60575235372 -5.456200509999988
# Guess LIKE 68.1954576144 -4.848974709999993
# Guess LEAVE 47.9207598818 -5.456200509999988
# Guess SAY 25.7226968393 -5.365685509999992
# Guess BUY 34.149710873 -4.822376509999998
# Guess HOUSE 30.6285860955 -5.365685509999992
# Guess KNOW 17.4257114736 -5.365685509999992
# Guess CORN 54.3538533343 -5.365685509999992
# Guess CORN1 39.6237994872 -5.456200509999988
# Guess THINK 54.9231031369 -4.783500709999998
# Guess NOT 45.3120644755 -5.103183509999994
# Guess PAST 36.0534715752 -5.456200509999988
# Guess LIVE -74.6349329793 -5.456200509999988
# Guess CHICAGO -81.2850951672 -5.456200509999988
# Guess CAR 34.4969488805 -4.591276709999988
# Guess SHOULD 47.7033344828 -5.259952509999991
# Guess DECIDE -27.0489475064 -5.456200509999988
# Guess VISIT 48.3372121531 -4.897437509999989
# Guess MOVIE 10.6283294599 -5.456200509999988
# Guess WANT -39.8167191343 -5.456200509999988
# Guess SELL 9.18932817576 -5.365685509999992
# Guess TOMORROW -19.8122332016 -5.456200509999988
# Guess NEXT-WEEK -108.075114297 -5.456200509999988
# Guess NEW-YORK 28.2592709438 -5.456200509999988
# Guess LAST-WEEK -29.2782716269 -5.456200509999988
# Guess WILL 21.8612093116 -5.456200509999988
# Guess FINISH 58.821390042 -5.365685509999992
# Guess ANN -22.5646554649 -5.456200509999988
# Guess READ 34.3852515803 -5.365685509999992
# Guess BOOK 34.8406725442 -4.583276709999993
# Guess CHOCOLATE 13.155033516 -5.456200509999988
# Guess FIND -64.7911850802 -5.456200509999988
# Guess SOMETHING-ONE 40.7424525054 -4.63377770999999
# Guess POSS 55.8723257979 -4.897437509999989
# Guess BROTHER 45.9197374927 -5.365685509999992
# Guess ARRIVE 27.3576248049 -4.758397509999995
# Guess HERE 29.2493184956 -5.456200509999988
# Guess GIVE 63.3976895033 -4.517025709999999
# Guess MAN 4.00212967393 -4.783500709999998
# Guess NEW 52.1637036697 -4.762628709999987
# Guess COAT -54.4150413939 -5.456200509999988
# Guess WOMAN 61.138738201 -4.781254709999999
# Guess GIVE1 53.9744440636 -5.456200509999988
# Guess HAVE 33.888425418 -4.733749709999998
# Guess FRANK 25.7726210028 -5.365685509999992
# Guess BREAK-DOWN 23.5934304371 -5.456200509999988
# Guess SEARCH-FOR 48.6624910232 -5.456200509999988
# Guess WHO 63.6686043212 -4.425103709999988
# Guess WHAT 53.2957450295 -4.497877509999995
# Guess LEG 34.4155751826 -5.456200509999988
# Guess FRIEND -14.6785424558 -5.456200509999988
# Guess CANDY 36.8359809536 -5.456200509999988
# Guess BLUE 17.463331329 -5.456200509999988
# Guess SUE -3.82475832348 -5.456200509999988
# Guess BUY1 26.5630294808 -5.456200509999988
# Guess STOLEN 47.9971878129 -5.456200509999988
# Guess OLD 43.9019566686 -5.456200509999988
# Guess STUDENT 12.1817883508 -5.456200509999988
# Guess VIDEOTAPE 42.4330667237 -5.365685509999992
# Guess BORROW -82.0924976695 -5.456200509999988
# Guess MOTHER 11.6200774144 -5.259952509999991
# Guess POTATO 32.146969251 -5.456200509999988
# Guess TELL 60.4686666673 -5.365685509999992
# Guess BILL 53.1254203092 -5.365685509999992
# Guess THROW 64.3397103448 -5.456200509999988
# Guess APPLE 31.8438626071 -5.365685509999992
# Guess NAME -18.2781977642 -5.456200509999988
# Guess SHOOT 6.43317188588 -5.456200509999988
# Guess SAY-1P 43.5177035313 -4.783500709999998
# Guess SELF -37.0077116988 -5.456200509999988
# Guess GROUP -34.2937299318 -5.456200509999988
# Guess JANA 8.95888806864 -5.456200509999988
# Guess TOY1 57.6239324138 -5.456200509999988
# Guess MANY 21.917008374 -5.456200509999988
# Guess TOY -60.264045608 -5.456200509999988
# Guess ALL 17.0744781379 -5.456200509999988
# Guess BOY -3.34591732528 -5.365685509999992
# Guess TEACHER -28.5733199259 -5.365685509999992
# Guess GIRL 45.6933411278 -4.762628709999987
# Guess BOX 15.1149123915 -5.365685509999992
# Guess GIVE2 -32.5242745345 -5.456200509999988
# Guess GIVE3 36.5258051541 -5.456200509999988
# Guess GET -90.8213147856 -5.456200509999988
# Guess PUTASIDE 68.6272071245 -5.456200509999988
#
# **** WER = 0.898876404494382
# Total correct: 18 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN WRITE HOMEWORK                                           JOHN WRITE HOMEWORK
#     7: JOHN CAN GO CAN                                               JOHN CAN GO CAN
#    12: JOHN CAN GO CAN                                               JOHN CAN GO CAN
#    21: JOHN FISH WONT *MARY *HOUSE *GO *FUTURE *MARY                 JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX

# %%
import my_recognizer
reload(my_recognizer)
from my_recognizer import recognize_gram_3_only_best
guesses = recognize_gram_3_only_best(models, test_set,model_arpa,C=10,n_best=20)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.5
# Total correct: 89 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN WRITE HOMEWORK                                           JOHN WRITE HOMEWORK
#     7: JOHN CAN GO *ARRIVE                                           JOHN CAN GO CAN
#    12: JOHN CAN GO CAN                                               JOHN CAN GO CAN
#    21: JOHN FISH WONT *MARY *HOUSE *GO *FUTURE *MARY                 JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX
#    28: JOHN *IX IX IX IX                                             JOHN LIKE IX IX IX
#    30: JOHN LIKE IX IX IX                                            JOHN LIKE IX IX IX
#    36: *JOHN *JOHN *GIVE IX *JOHN *IX                                MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN IX *WHO *WHO *MARY                                       JOHN IX THINK MARY LOVE
#    43: JOHN *IX BUY HOUSE                                            JOHN MUST BUY HOUSE
#    50: *JOHN *SHOULD BUY CAR *FUTURE                                 FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *GIVE *IX BUY HOUSE                                      JOHN SHOULD NOT BUY HOUSE
#    57: JOHN *GIVE *IX *IX                                            JOHN DECIDE VISIT MARY
#    67: JOHN *IX *IX *IX HOUSE                                        JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *FUTURE *GO MARY                                         JOHN WILL VISIT MARY
#    74: JOHN *IX VISIT MARY                                           JOHN NOT VISIT MARY
#    77: *JOHN *ARRIVE MARY                                            ANN BLAME MARY
#    84: *JOHN *GO *IX BOOK                                            IX-1P FIND SOMETHING-ONE BOOK
#    89: JOHN IX GIVE *IX *GIVE *WHAT *CAN                             JOHN IX GIVE MAN IX NEW COAT
#    90: JOHN GIVE IX *GIVE WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *IX IX *IX *IX *JOHN                                     JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: *IX NEW CAR *HOUSE                                            POSS NEW CAR BREAK-DOWN
#   105: JOHN *IX                                                      JOHN LEG
#   107: JOHN POSS *VISIT *MARY *JOHN                                  JOHN POSS FRIEND HAVE CANDY
#   108: *IX *STUDENT                                                  WOMAN ARRIVE
#   113: *JOHN *VISIT *MARY *JOHN *LOVE                                IX CAR BLUE SUE BUY
#   119: *JOHN *CAR IX CAR *WHO                                        SUE BUY IX CAR BLUE
#   122: JOHN *CAR BOOK                                                JOHN READ BOOK
#   139: JOHN BUY *HOUSE *JOHN *LOVE                                   JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY *HOUSE WHAT BOOK                                     JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE JOHN WHO                                                 LOVE JOHN WHO
#   167: JOHN *GIVE *IX LOVE MARY                                      JOHN IX SAY LOVE MARY
#   171: JOHN *SHOULD *ARRIVE                                          JOHN MARY BLAME
#   174: *CAR *JOHN GIVE1 *MARY *BLAME                                 PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN ARRIVE                                                   JOHN ARRIVE
#   184: *GIVE *GIVE1 *GIVE1 TEACHER *YESTERDAY                        ALL BOY GIVE TEACHER APPLE
#   189: JOHN GIVE *IX *BOOK                                           JOHN GIVE GIRL BOX
#   193: JOHN *IX *HAVE BOX                                            JOHN GIVE GIRL BOX
#   199: *JOHN *LOVE *MARY                                             LIKE CHOCOLATE WHO
#   201: JOHN *IX *WHO *POSS *VISIT HOUSE                              JOHN TELL MARY IX-1P BUY HOUSE

# %%
from imp import reload
import arpa
features = features_polar # change as needed
model_selector = SelectorBIC # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
guesses = recognize_gram_3_only_best(models, test_set,model_arpa,C=10,n_best=40)
show_errors(guesses, test_set)
# Out:
# **** WER = 0.5112359550561798
# Total correct: 87 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *BROTHER *ARRIVE                                         JOHN WRITE HOMEWORK
#     7: JOHN CAN GO CAN                                               JOHN CAN GO CAN
#    12: JOHN *WHAT *JOHN CAN                                          JOHN CAN GO CAN
#    21: JOHN *NEW *CAR *WHO *WHAT *WHAT *JOHN *WHO                    JOHN FISH WONT EAT BUT CAN EAT CHICKEN
